# %%
import pandas as pd
import matplotlib.pyplot as plt
import datetime

# %%
data = pd.read_excel('Cumulative_Snoqualmie_Pass_Delay_Closures_1992_2018.xlsx', header=[1])

# %%
data.head().T
# Out:
#                                                                                          0  \
# INCIDENT START TIMES FOR EACH DIRECTION                                1992-11-21 12:25:00
# SECONDARY INCIDENTS START TIMES                                                        NaN
# DIRECTION                                                                               WB
# GEOGRAPHIC                                                                             NaN
# MP                                                                                     NaN
# TYPE                                                                                   NaN
#  REMARKS / DESCRIPTION                   MP 56 & 52 TEMP DELAY TO ENABLE SEARCH & RESCU...
# INCIDENT END TIMES - DIRECTIONAL                                       1992-11-21 13:00:00
# SECONDARY INCIDENTS END TIMES                                                          NaN
# Delay Time Total                                                                  00:35:00
# WEATHER                                                                                NaN
# Unnamed: 11                                                                            NaN
# Unnamed: 12                                                                            NaN
# Unnamed: 13                                                                            NaN
# Unnamed: 14                                                                            NaN
#
#                                                                                          1  \
# INCIDENT START TIMES FOR EACH DIRECTION                                1992-11-21 13:13:00
# SECONDARY INCIDENTS START TIMES                                                        NaN
# DIRECTION                                                                               EB
# GEOGRAPHIC                                                                             NaN
# MP                                                                                     NaN
# TYPE                                                                                   NaN
#  REMARKS / DESCRIPTION                   MP 56 & 52 TEMP DELAY TO ENABLE SEARCH & RESCU...
# INCIDENT END TIMES - DIRECTIONAL                                       1992-11-21 14:05:00
# SECONDARY INCIDENTS END TIMES                                                          NaN
# Delay Time Total                                                                  00:52:00
# WEATHER                                                                                NaN
# Unnamed: 11                                                                            NaN
# Unnamed: 12                                                                            NaN
# Unnamed: 13                                                                            NaN
# Unnamed: 14                                                                            NaN
#
#                                                                                          2  \
# INCIDENT START TIMES FOR EACH DIRECTION                                1992-11-21 14:30:00
# SECONDARY INCIDENTS START TIMES                                                        NaN
# DIRECTION                                                                               EB
# GEOGRAPHIC                                                                             NaN
# MP                                                                                     NaN
# TYPE                                                                                   NaN
#  REMARKS / DESCRIPTION                   DELAYS DUE TO SPUNOUT TRUCKS TRAFFIC WORKING T...
# INCIDENT END TIMES - DIRECTIONAL                                       1992-11-21 15:30:00
# SECONDARY INCIDENTS END TIMES                                                          NaN
# Delay Time Total                                                                  01:00:00
# WEATHER                                                                                NaN
# Unnamed: 11                                                                            NaN
# Unnamed: 12                                                                            NaN
# Unnamed: 13                                                                            NaN
# Unnamed: 14                                                                            NaN
#
#                                                                               3  \
# INCIDENT START TIMES FOR EACH DIRECTION                     1992-11-21 14:33:00
# SECONDARY INCIDENTS START TIMES                                             NaN
# DIRECTION                                                                    WB
# GEOGRAPHIC                                                                  NaN
# MP                                                                          NaN
# TYPE                                                                        NaN
#  REMARKS / DESCRIPTION                   LOG TRUCK ACCIDENT LOG BLOCKING LANE 3
# INCIDENT END TIMES - DIRECTIONAL                            1992-11-21 15:30:00
# SECONDARY INCIDENTS END TIMES                                               NaN
# Delay Time Total                                                       00:57:00
# WEATHER                                                                     NaN
# Unnamed: 11                                                                 NaN
# Unnamed: 12                                                                 NaN
# Unnamed: 13                                                                 NaN
# Unnamed: 14                                                                 NaN
#
#                                                                                  4
# INCIDENT START TIMES FOR EACH DIRECTION                        1992-11-30 18:28:00
# SECONDARY INCIDENTS START TIMES                                                NaN
# DIRECTION                                                                       EB
# GEOGRAPHIC                                                                     NaN
# MP                                                                             NaN
# TYPE                                                                           NaN
#  REMARKS / DESCRIPTION                   EB 60 TANKER / CAR COLLISION PT. BLOCKING
# INCIDENT END TIMES - DIRECTIONAL                               1992-11-30 22:10:00
# SECONDARY INCIDENTS END TIMES                                                  NaN
# Delay Time Total                                                          03:42:00
# WEATHER                                                                        NaN
# Unnamed: 11                                                                    NaN
# Unnamed: 12                                                                    NaN
# Unnamed: 13                                                                    NaN
# Unnamed: 14                                                                    NaN

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1632 entries, 0 to 1631
# Data columns (total 15 columns):
# INCIDENT START TIMES FOR EACH DIRECTION    1549 non-null datetime64[ns]
# SECONDARY INCIDENTS START TIMES            73 non-null object
# DIRECTION                                  1618 non-null object
# GEOGRAPHIC                                 839 non-null object
# MP                                         901 non-null object
# TYPE                                       705 non-null object
#  REMARKS / DESCRIPTION                     1628 non-null object
# INCIDENT END TIMES - DIRECTIONAL           1549 non-null object
# SECONDARY INCIDENTS END TIMES              65 non-null object
# Delay Time Total                           1627 non-null object
# WEATHER                                    625 non-null object
# Unnamed: 11                                0 non-null float64
# Unnamed: 12                                24 non-null object
# Unnamed: 13                                0 non-null float64
# Unnamed: 14                                26 non-null object
# dtypes: datetime64[ns](1), float64(2), object(12)
# memory usage: 191.3+ KB

# %%
data.drop(data.columns[[11,12,13,14]], axis=1, inplace=True)

# %%
data.head().T
# Out:
#                                                                                          0  \
# INCIDENT START TIMES FOR EACH DIRECTION                                1992-11-21 12:25:00
# SECONDARY INCIDENTS START TIMES                                                        NaN
# DIRECTION                                                                               WB
# GEOGRAPHIC                                                                             NaN
# MP                                                                                     NaN
# TYPE                                                                                   NaN
#  REMARKS / DESCRIPTION                   MP 56 & 52 TEMP DELAY TO ENABLE SEARCH & RESCU...
# INCIDENT END TIMES - DIRECTIONAL                                       1992-11-21 13:00:00
# SECONDARY INCIDENTS END TIMES                                                          NaN
# Delay Time Total                                                                  00:35:00
# WEATHER                                                                                NaN
#
#                                                                                          1  \
# INCIDENT START TIMES FOR EACH DIRECTION                                1992-11-21 13:13:00
# SECONDARY INCIDENTS START TIMES                                                        NaN
# DIRECTION                                                                               EB
# GEOGRAPHIC                                                                             NaN
# MP                                                                                     NaN
# TYPE                                                                                   NaN
#  REMARKS / DESCRIPTION                   MP 56 & 52 TEMP DELAY TO ENABLE SEARCH & RESCU...
# INCIDENT END TIMES - DIRECTIONAL                                       1992-11-21 14:05:00
# SECONDARY INCIDENTS END TIMES                                                          NaN
# Delay Time Total                                                                  00:52:00
# WEATHER                                                                                NaN
#
#                                                                                          2  \
# INCIDENT START TIMES FOR EACH DIRECTION                                1992-11-21 14:30:00
# SECONDARY INCIDENTS START TIMES                                                        NaN
# DIRECTION                                                                               EB
# GEOGRAPHIC                                                                             NaN
# MP                                                                                     NaN
# TYPE                                                                                   NaN
#  REMARKS / DESCRIPTION                   DELAYS DUE TO SPUNOUT TRUCKS TRAFFIC WORKING T...
# INCIDENT END TIMES - DIRECTIONAL                                       1992-11-21 15:30:00
# SECONDARY INCIDENTS END TIMES                                                          NaN
# Delay Time Total                                                                  01:00:00
# WEATHER                                                                                NaN
#
#                                                                               3  \
# INCIDENT START TIMES FOR EACH DIRECTION                     1992-11-21 14:33:00
# SECONDARY INCIDENTS START TIMES                                             NaN
# DIRECTION                                                                    WB
# GEOGRAPHIC                                                                  NaN
# MP                                                                          NaN
# TYPE                                                                        NaN
#  REMARKS / DESCRIPTION                   LOG TRUCK ACCIDENT LOG BLOCKING LANE 3
# INCIDENT END TIMES - DIRECTIONAL                            1992-11-21 15:30:00
# SECONDARY INCIDENTS END TIMES                                               NaN
# Delay Time Total                                                       00:57:00
# WEATHER                                                                     NaN
#
#                                                                                  4
# INCIDENT START TIMES FOR EACH DIRECTION                        1992-11-30 18:28:00
# SECONDARY INCIDENTS START TIMES                                                NaN
# DIRECTION                                                                       EB
# GEOGRAPHIC                                                                     NaN
# MP                                                                             NaN
# TYPE                                                                           NaN
#  REMARKS / DESCRIPTION                   EB 60 TANKER / CAR COLLISION PT. BLOCKING
# INCIDENT END TIMES - DIRECTIONAL                               1992-11-30 22:10:00
# SECONDARY INCIDENTS END TIMES                                                  NaN
# Delay Time Total                                                          03:42:00
# WEATHER                                                                        NaN

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1632 entries, 0 to 1631
# Data columns (total 11 columns):
# INCIDENT START TIMES FOR EACH DIRECTION    1549 non-null datetime64[ns]
# SECONDARY INCIDENTS START TIMES            73 non-null object
# DIRECTION                                  1618 non-null object
# GEOGRAPHIC                                 839 non-null object
# MP                                         901 non-null object
# TYPE                                       705 non-null object
#  REMARKS / DESCRIPTION                     1628 non-null object
# INCIDENT END TIMES - DIRECTIONAL           1549 non-null object
# SECONDARY INCIDENTS END TIMES              65 non-null object
# Delay Time Total                           1627 non-null object
# WEATHER                                    625 non-null object
# dtypes: datetime64[ns](1), object(10)
# memory usage: 140.3+ KB

# %%
data.tail().T
# Out:
#                                                                                       1627  \
# INCIDENT START TIMES FOR EACH DIRECTION                                2018-03-04 20:31:00
# SECONDARY INCIDENTS START TIMES                                                        NaN
# DIRECTION                                                                               EB
# GEOGRAPHIC                                                                      NORTH BEND
# MP                                                                                      34
# TYPE                                                                           WX/TRACTION
#  REMARKS / DESCRIPTION                   MULTIPLE UNCHAINED & SPUN OUT VEHICLES AND MUL...
# INCIDENT END TIMES - DIRECTIONAL                                       2018-03-05 00:00:00
# SECONDARY INCIDENTS END TIMES                                                          NaN
# Delay Time Total                                                                  03:29:00
# WEATHER                                                                        HEAVY SNOW
#
#                                                                      1628  \
# INCIDENT START TIMES FOR EACH DIRECTION               2018-03-29 09:02:00
# SECONDARY INCIDENTS START TIMES                                       NaN
# DIRECTION                                                              EB
# GEOGRAPHIC                                         NORTH BEND DENNY CREEK
# MP                                                                  34/47
# TYPE                                     SCHEDULED AVALANCHE CONTROL WORK
#  REMARKS / DESCRIPTION                                       TANK MISSION
# INCIDENT END TIMES - DIRECTIONAL                      2018-03-29 09:39:00
# SECONDARY INCIDENTS END TIMES                                         NaN
# Delay Time Total                                                 00:37:00
# WEATHER                                                               FOG
#
#                                                                      1629  \
# INCIDENT START TIMES FOR EACH DIRECTION               2018-03-29 09:02:00
# SECONDARY INCIDENTS START TIMES                                       NaN
# DIRECTION                                                              WB
# GEOGRAPHIC                                                  EASTON, MP 52
# MP                                                                  52/70
# TYPE                                     SCHEDULED AVALANCHE CONTROL WORK
#  REMARKS / DESCRIPTION                                       TANK MISSION
# INCIDENT END TIMES - DIRECTIONAL                      2018-03-29 09:42:00
# SECONDARY INCIDENTS END TIMES                                         NaN
# Delay Time Total                                                 00:40:00
# WEATHER                                                               FOG
#
#                                                                                       1630  \
# INCIDENT START TIMES FOR EACH DIRECTION                                2018-04-01 22:29:00
# SECONDARY INCIDENTS START TIMES                                                        NaN
# DIRECTION                                                                               WB
# GEOGRAPHIC                                           EASTON/GOLD CREEK/CLE ELUM/ELLENSBURG
# MP                                                                            56/70/84/106
# TYPE                                                                           WX/TRACTION
#  REMARKS / DESCRIPTION                   MULTIPLE UNCHAINED & SPUN OUT VEHICLES AND MUL...
# INCIDENT END TIMES - DIRECTIONAL                                       2018-04-02 07:41:00
# SECONDARY INCIDENTS END TIMES                                                          NaN
# Delay Time Total                                                                  09:12:00
# WEATHER                                                                        HEAVY SNOW
#
#                                                                                       1631
# INCIDENT START TIMES FOR EACH DIRECTION                                2018-04-01 23:09:00
# SECONDARY INCIDENTS START TIMES                                                        NaN
# DIRECTION                                                                               EB
# GEOGRAPHIC                                                          NORTH BEND/DENNY CREEK
# MP                                                                                   34/47
# TYPE                                                                           WX/TRACTION
#  REMARKS / DESCRIPTION                   MULTIPLE UNCHAINED & SPUN OUT VEHICLES AND MUL...
# INCIDENT END TIMES - DIRECTIONAL                                       2018-04-02 07:58:00
# SECONDARY INCIDENTS END TIMES                                                          NaN
# Delay Time Total                                                                  08:49:00
# WEATHER                                                                        HEAVY SNOW

# %%
data.drop(data.columns[[1,8]], axis=1, inplace=True)

# %%
data.head(10).T
# Out:
#                                                                                          0  \
# INCIDENT START TIMES FOR EACH DIRECTION                                1992-11-21 12:25:00
# DIRECTION                                                                               WB
# GEOGRAPHIC                                                                             NaN
# MP                                                                                     NaN
# TYPE                                                                                   NaN
#  REMARKS / DESCRIPTION                   MP 56 & 52 TEMP DELAY TO ENABLE SEARCH & RESCU...
# INCIDENT END TIMES - DIRECTIONAL                                       1992-11-21 13:00:00
# Delay Time Total                                                                  00:35:00
# WEATHER                                                                                NaN
#
#                                                                                          1  \
# INCIDENT START TIMES FOR EACH DIRECTION                                1992-11-21 13:13:00
# DIRECTION                                                                               EB
# GEOGRAPHIC                                                                             NaN
# MP                                                                                     NaN
# TYPE                                                                                   NaN
#  REMARKS / DESCRIPTION                   MP 56 & 52 TEMP DELAY TO ENABLE SEARCH & RESCU...
# INCIDENT END TIMES - DIRECTIONAL                                       1992-11-21 14:05:00
# Delay Time Total                                                                  00:52:00
# WEATHER                                                                                NaN
#
#                                                                                          2  \
# INCIDENT START TIMES FOR EACH DIRECTION                                1992-11-21 14:30:00
# DIRECTION                                                                               EB
# GEOGRAPHIC                                                                             NaN
# MP                                                                                     NaN
# TYPE                                                                                   NaN
#  REMARKS / DESCRIPTION                   DELAYS DUE TO SPUNOUT TRUCKS TRAFFIC WORKING T...
# INCIDENT END TIMES - DIRECTIONAL                                       1992-11-21 15:30:00
# Delay Time Total                                                                  01:00:00
# WEATHER                                                                                NaN
#
#                                                                               3  \
# INCIDENT START TIMES FOR EACH DIRECTION                     1992-11-21 14:33:00
# DIRECTION                                                                    WB
# GEOGRAPHIC                                                                  NaN
# MP                                                                          NaN
# TYPE                                                                        NaN
#  REMARKS / DESCRIPTION                   LOG TRUCK ACCIDENT LOG BLOCKING LANE 3
# INCIDENT END TIMES - DIRECTIONAL                            1992-11-21 15:30:00
# Delay Time Total                                                       00:57:00
# WEATHER                                                                     NaN
#
#                                                                                  4  \
# INCIDENT START TIMES FOR EACH DIRECTION                        1992-11-30 18:28:00
# DIRECTION                                                                       EB
# GEOGRAPHIC                                                                     NaN
# MP                                                                             NaN
# TYPE                                                                           NaN
#  REMARKS / DESCRIPTION                   EB 60 TANKER / CAR COLLISION PT. BLOCKING
# INCIDENT END TIMES - DIRECTIONAL                               1992-11-30 22:10:00
# Delay Time Total                                                          03:42:00
# WEATHER                                                                        NaN
#
#                                                                               5  \
# INCIDENT START TIMES FOR EACH DIRECTION                     1992-12-08 05:19:00
# DIRECTION                                                                    EB
# GEOGRAPHIC                                                                  NaN
# MP                                                                          NaN
# TYPE                                                                        NaN
#  REMARKS / DESCRIPTION                   36 LANES BLOCKED DUE TO SPUN OUT SEMIS
# INCIDENT END TIMES - DIRECTIONAL                            1992-12-08 06:06:00
# Delay Time Total                                                       00:47:00
# WEATHER                                                                     NaN
#
#                                                                            6  \
# INCIDENT START TIMES FOR EACH DIRECTION                                  NaT
# DIRECTION                                                                 EB
# GEOGRAPHIC                                                               NaN
# MP                                                                       NaN
# TYPE                                                                     NaN
#  REMARKS / DESCRIPTION                   EB STOPPED AT EDGEWICK DUE TO ABOVE
# INCIDENT END TIMES - DIRECTIONAL                                         NaN
# Delay Time Total                                                    00:00:00
# WEATHER                                                                  NaN
#
#                                                                                 7  \
# INCIDENT START TIMES FOR EACH DIRECTION                       1992-12-08 16:19:00
# DIRECTION                                                                      EB
# GEOGRAPHIC                                                                    NaN
# MP                                                                            NaN
# TYPE                                                                          NaN
#  REMARKS / DESCRIPTION                   47 AVALANCHE CONTROL AIRPLANE CURVE 51.5
# INCIDENT END TIMES - DIRECTIONAL                              1992-12-08 16:40:00
# Delay Time Total                                                         00:21:00
# WEATHER                                                                       NaN
#
#                                                                            8  \
# INCIDENT START TIMES FOR EACH DIRECTION                  1992-12-09 10:28:00
# DIRECTION                                                                 EB
# GEOGRAPHIC                                                               NaN
# MP                                                                       NaN
# TYPE                                                                     NaN
#  REMARKS / DESCRIPTION                   56 AVALANCHE CONTROL EAST SNOW SHED
# INCIDENT END TIMES - DIRECTIONAL                         1992-12-09 10:45:00
# Delay Time Total                                                    00:17:00
# WEATHER                                                                  NaN
#
#                                                                                 9
# INCIDENT START TIMES FOR EACH DIRECTION                       1992-12-10 08:43:00
# DIRECTION                                                                     EB
# GEOGRAPHIC                                                                    NaN
# MP                                                                            NaN
# TYPE                                                                          NaN
#  REMARKS / DESCRIPTION                   47 AVALANCHE CONTROL AIRPLANE CURVE 51.5
# INCIDENT END TIMES - DIRECTIONAL                              1992-12-10 09:22:00
# Delay Time Total                                                         00:39:00
# WEATHER                                                                       NaN

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1632 entries, 0 to 1631
# Data columns (total 9 columns):
# INCIDENT START TIMES FOR EACH DIRECTION    1549 non-null datetime64[ns]
# DIRECTION                                  1618 non-null object
# GEOGRAPHIC                                 839 non-null object
# MP                                         901 non-null object
# TYPE                                       705 non-null object
#  REMARKS / DESCRIPTION                     1628 non-null object
# INCIDENT END TIMES - DIRECTIONAL           1549 non-null object
# Delay Time Total                           1627 non-null object
# WEATHER                                    625 non-null object
# dtypes: datetime64[ns](1), object(8)
# memory usage: 114.8+ KB

# %%
data.tail().T
# Out:
#                                                                                       1627  \
# INCIDENT START TIMES FOR EACH DIRECTION                                2018-03-04 20:31:00
# DIRECTION                                                                               EB
# GEOGRAPHIC                                                                      NORTH BEND
# MP                                                                                      34
# TYPE                                                                           WX/TRACTION
#  REMARKS / DESCRIPTION                   MULTIPLE UNCHAINED & SPUN OUT VEHICLES AND MUL...
# INCIDENT END TIMES - DIRECTIONAL                                       2018-03-05 00:00:00
# Delay Time Total                                                                  03:29:00
# WEATHER                                                                        HEAVY SNOW
#
#                                                                      1628  \
# INCIDENT START TIMES FOR EACH DIRECTION               2018-03-29 09:02:00
# DIRECTION                                                              EB
# GEOGRAPHIC                                         NORTH BEND DENNY CREEK
# MP                                                                  34/47
# TYPE                                     SCHEDULED AVALANCHE CONTROL WORK
#  REMARKS / DESCRIPTION                                       TANK MISSION
# INCIDENT END TIMES - DIRECTIONAL                      2018-03-29 09:39:00
# Delay Time Total                                                 00:37:00
# WEATHER                                                               FOG
#
#                                                                      1629  \
# INCIDENT START TIMES FOR EACH DIRECTION               2018-03-29 09:02:00
# DIRECTION                                                              WB
# GEOGRAPHIC                                                  EASTON, MP 52
# MP                                                                  52/70
# TYPE                                     SCHEDULED AVALANCHE CONTROL WORK
#  REMARKS / DESCRIPTION                                       TANK MISSION
# INCIDENT END TIMES - DIRECTIONAL                      2018-03-29 09:42:00
# Delay Time Total                                                 00:40:00
# WEATHER                                                               FOG
#
#                                                                                       1630  \
# INCIDENT START TIMES FOR EACH DIRECTION                                2018-04-01 22:29:00
# DIRECTION                                                                               WB
# GEOGRAPHIC                                           EASTON/GOLD CREEK/CLE ELUM/ELLENSBURG
# MP                                                                            56/70/84/106
# TYPE                                                                           WX/TRACTION
#  REMARKS / DESCRIPTION                   MULTIPLE UNCHAINED & SPUN OUT VEHICLES AND MUL...
# INCIDENT END TIMES - DIRECTIONAL                                       2018-04-02 07:41:00
# Delay Time Total                                                                  09:12:00
# WEATHER                                                                        HEAVY SNOW
#
#                                                                                       1631
# INCIDENT START TIMES FOR EACH DIRECTION                                2018-04-01 23:09:00
# DIRECTION                                                                               EB
# GEOGRAPHIC                                                          NORTH BEND/DENNY CREEK
# MP                                                                                   34/47
# TYPE                                                                           WX/TRACTION
#  REMARKS / DESCRIPTION                   MULTIPLE UNCHAINED & SPUN OUT VEHICLES AND MUL...
# INCIDENT END TIMES - DIRECTIONAL                                       2018-04-02 07:58:00
# Delay Time Total                                                                  08:49:00
# WEATHER                                                                        HEAVY SNOW

# %%
data.rename(columns={'INCIDENT START TIMES FOR EACH DIRECTION':'date'}, inplace=True)

# %%
data.tail().T
# Out:
#                                                                                1627  \
# date                                                            2018-03-04 20:31:00
# SECONDARY INCIDENTS START TIMES                                                 NaN
# DIRECTION                                                                        EB
# GEOGRAPHIC                                                               NORTH BEND
# MP                                                                               34
# TYPE                                                                    WX/TRACTION
#  REMARKS / DESCRIPTION            MULTIPLE UNCHAINED & SPUN OUT VEHICLES AND MUL...
# INCIDENT END TIMES - DIRECTIONAL                                2018-03-05 00:00:00
# SECONDARY INCIDENTS END TIMES                                                   NaN
# Delay Time Total                                                           03:29:00
# WEATHER                                                                 HEAVY SNOW
#
#                                                               1628  \
# date                                           2018-03-29 09:02:00
# SECONDARY INCIDENTS START TIMES                                NaN
# DIRECTION                                                       EB
# GEOGRAPHIC                                  NORTH BEND DENNY CREEK
# MP                                                           34/47
# TYPE                              SCHEDULED AVALANCHE CONTROL WORK
#  REMARKS / DESCRIPTION                                TANK MISSION
# INCIDENT END TIMES - DIRECTIONAL               2018-03-29 09:39:00
# SECONDARY INCIDENTS END TIMES                                  NaN
# Delay Time Total                                          00:37:00
# WEATHER                                                        FOG
#
#                                                               1629  \
# date                                           2018-03-29 09:02:00
# SECONDARY INCIDENTS START TIMES                                NaN
# DIRECTION                                                       WB
# GEOGRAPHIC                                           EASTON, MP 52
# MP                                                           52/70
# TYPE                              SCHEDULED AVALANCHE CONTROL WORK
#  REMARKS / DESCRIPTION                                TANK MISSION
# INCIDENT END TIMES - DIRECTIONAL               2018-03-29 09:42:00
# SECONDARY INCIDENTS END TIMES                                  NaN
# Delay Time Total                                          00:40:00
# WEATHER                                                        FOG
#
#                                                                                1630  \
# date                                                            2018-04-01 22:29:00
# SECONDARY INCIDENTS START TIMES                                                 NaN
# DIRECTION                                                                        WB
# GEOGRAPHIC                                    EASTON/GOLD CREEK/CLE ELUM/ELLENSBURG
# MP                                                                     56/70/84/106
# TYPE                                                                    WX/TRACTION
#  REMARKS / DESCRIPTION            MULTIPLE UNCHAINED & SPUN OUT VEHICLES AND MUL...
# INCIDENT END TIMES - DIRECTIONAL                                2018-04-02 07:41:00
# SECONDARY INCIDENTS END TIMES                                                   NaN
# Delay Time Total                                                           09:12:00
# WEATHER                                                                 HEAVY SNOW
#
#                                                                                1631
# date                                                            2018-04-01 23:09:00
# SECONDARY INCIDENTS START TIMES                                                 NaN
# DIRECTION                                                                        EB
# GEOGRAPHIC                                                   NORTH BEND/DENNY CREEK
# MP                                                                            34/47
# TYPE                                                                    WX/TRACTION
#  REMARKS / DESCRIPTION            MULTIPLE UNCHAINED & SPUN OUT VEHICLES AND MUL...
# INCIDENT END TIMES - DIRECTIONAL                                2018-04-02 07:58:00
# SECONDARY INCIDENTS END TIMES                                                   NaN
# Delay Time Total                                                           08:49:00
# WEATHER                                                                 HEAVY SNOW

# %%
df = data[(data['date'] > '2007-01-01')]

# %%
df.head().T
# Out:
#                                                                           830  \
# date                                                      2007-01-02 14:31:00
# SECONDARY INCIDENTS START TIMES                                           NaN
# DIRECTION                                                                  EB
# GEOGRAPHIC                                                          Snow Shed
# MP                                                                         58
# TYPE                                                                      NaN
#  REMARKS / DESCRIPTION            Avalanche Control ESS traffic stopped eb 56
# INCIDENT END TIMES - DIRECTIONAL                          2007-01-02 16:45:00
# SECONDARY INCIDENTS END TIMES                                             NaN
# Delay Time Total                                                     02:14:00
# WEATHER                                                               Raining
#
#                                                                           831  \
# date                                                      2007-01-02 15:00:00
# SECONDARY INCIDENTS START TIMES                                           NaN
# DIRECTION                                                                  WB
# GEOGRAPHIC                                                          Snow Shed
# MP                                                                         58
# TYPE                                                                      NaN
#  REMARKS / DESCRIPTION            Avalanche Control ESS traffic stopped wb 61
# INCIDENT END TIMES - DIRECTIONAL                          2007-01-02 15:44:00
# SECONDARY INCIDENTS END TIMES                                             NaN
# Delay Time Total                                                     00:44:00
# WEATHER                                                               Raining
#
#                                                                                832  \
# date                                                           2007-01-02 19:23:00
# SECONDARY INCIDENTS START TIMES                                                NaN
# DIRECTION                                                                       WB
# GEOGRAPHIC                                                               Denny Mt.
# MP                                                                              51
# TYPE                                                                           NaN
#  REMARKS / DESCRIPTION            Avalanche Control MP 51 WB traffic stopped wb 52
# INCIDENT END TIMES - DIRECTIONAL                               2007-01-02 19:33:00
# SECONDARY INCIDENTS END TIMES                                                  NaN
# Delay Time Total                                                          00:10:00
# WEATHER                                                                    Raining
#
#                                                                           833  \
# date                                                      2007-01-03 11:28:00
# SECONDARY INCIDENTS START TIMES                                           NaN
# DIRECTION                                                                  WB
# GEOGRAPHIC                                                          Snow Shed
# MP                                                                         58
# TYPE                                                                      NaN
#  REMARKS / DESCRIPTION            Avalanche Control ESS traffic stopped wb 61
# INCIDENT END TIMES - DIRECTIONAL                          2007-01-03 11:40:00
# SECONDARY INCIDENTS END TIMES                                             NaN
# Delay Time Total                                                     00:12:00
# WEATHER                                                       Mixed rain snow
#
#                                                                           834
# date                                                      2007-01-03 11:29:00
# SECONDARY INCIDENTS START TIMES                                           NaN
# DIRECTION                                                                  EB
# GEOGRAPHIC                                                          Snow Shed
# MP                                                                         58
# TYPE                                                                      NaN
#  REMARKS / DESCRIPTION            Avalanche Control ESS traffic stopped eb 56
# INCIDENT END TIMES - DIRECTIONAL                          2007-01-03 11:46:00
# SECONDARY INCIDENTS END TIMES                                             NaN
# Delay Time Total                                                     00:17:00
# WEATHER                                                       Mixed rain snow
