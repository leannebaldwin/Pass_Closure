# %%
import pandas as pd
import matplotlib.pyplot as plt
import datetime

# %%
data = pd.read_excel('Cumulative_Snoqualmie_Pass_Delay_Closures_1992_2018.xlsx', header=[1])

# %%
data.head().T
# Out:
#                                                                                          0  \
# INCIDENT START TIMES FOR EACH DIRECTION                                1992-11-21 12:25:00
# SECONDARY INCIDENTS START TIMES                                                        NaN
# DIRECTION                                                                               WB
# GEOGRAPHIC                                                                             NaN
# MP                                                                                     NaN
# TYPE                                                                                   NaN
#  REMARKS / DESCRIPTION                   MP 56 & 52 TEMP DELAY TO ENABLE SEARCH & RESCU...
# INCIDENT END TIMES - DIRECTIONAL                                       1992-11-21 13:00:00
# SECONDARY INCIDENTS END TIMES                                                          NaN
# Delay Time Total                                                                  00:35:00
# WEATHER                                                                                NaN
# Unnamed: 11                                                                            NaN
# Unnamed: 12                                                                            NaN
# Unnamed: 13                                                                            NaN
# Unnamed: 14                                                                            NaN
#
#                                                                                          1  \
# INCIDENT START TIMES FOR EACH DIRECTION                                1992-11-21 13:13:00
# SECONDARY INCIDENTS START TIMES                                                        NaN
# DIRECTION                                                                               EB
# GEOGRAPHIC                                                                             NaN
# MP                                                                                     NaN
# TYPE                                                                                   NaN
#  REMARKS / DESCRIPTION                   MP 56 & 52 TEMP DELAY TO ENABLE SEARCH & RESCU...
# INCIDENT END TIMES - DIRECTIONAL                                       1992-11-21 14:05:00
# SECONDARY INCIDENTS END TIMES                                                          NaN
# Delay Time Total                                                                  00:52:00
# WEATHER                                                                                NaN
# Unnamed: 11                                                                            NaN
# Unnamed: 12                                                                            NaN
# Unnamed: 13                                                                            NaN
# Unnamed: 14                                                                            NaN
#
#                                                                                          2  \
# INCIDENT START TIMES FOR EACH DIRECTION                                1992-11-21 14:30:00
# SECONDARY INCIDENTS START TIMES                                                        NaN
# DIRECTION                                                                               EB
# GEOGRAPHIC                                                                             NaN
# MP                                                                                     NaN
# TYPE                                                                                   NaN
#  REMARKS / DESCRIPTION                   DELAYS DUE TO SPUNOUT TRUCKS TRAFFIC WORKING T...
# INCIDENT END TIMES - DIRECTIONAL                                       1992-11-21 15:30:00
# SECONDARY INCIDENTS END TIMES                                                          NaN
# Delay Time Total                                                                  01:00:00
# WEATHER                                                                                NaN
# Unnamed: 11                                                                            NaN
# Unnamed: 12                                                                            NaN
# Unnamed: 13                                                                            NaN
# Unnamed: 14                                                                            NaN
#
#                                                                               3  \
# INCIDENT START TIMES FOR EACH DIRECTION                     1992-11-21 14:33:00
# SECONDARY INCIDENTS START TIMES                                             NaN
# DIRECTION                                                                    WB
# GEOGRAPHIC                                                                  NaN
# MP                                                                          NaN
# TYPE                                                                        NaN
#  REMARKS / DESCRIPTION                   LOG TRUCK ACCIDENT LOG BLOCKING LANE 3
# INCIDENT END TIMES - DIRECTIONAL                            1992-11-21 15:30:00
# SECONDARY INCIDENTS END TIMES                                               NaN
# Delay Time Total                                                       00:57:00
# WEATHER                                                                     NaN
# Unnamed: 11                                                                 NaN
# Unnamed: 12                                                                 NaN
# Unnamed: 13                                                                 NaN
# Unnamed: 14                                                                 NaN
#
#                                                                                  4
# INCIDENT START TIMES FOR EACH DIRECTION                        1992-11-30 18:28:00
# SECONDARY INCIDENTS START TIMES                                                NaN
# DIRECTION                                                                       EB
# GEOGRAPHIC                                                                     NaN
# MP                                                                             NaN
# TYPE                                                                           NaN
#  REMARKS / DESCRIPTION                   EB 60 TANKER / CAR COLLISION PT. BLOCKING
# INCIDENT END TIMES - DIRECTIONAL                               1992-11-30 22:10:00
# SECONDARY INCIDENTS END TIMES                                                  NaN
# Delay Time Total                                                          03:42:00
# WEATHER                                                                        NaN
# Unnamed: 11                                                                    NaN
# Unnamed: 12                                                                    NaN
# Unnamed: 13                                                                    NaN
# Unnamed: 14                                                                    NaN

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1632 entries, 0 to 1631
# Data columns (total 15 columns):
# INCIDENT START TIMES FOR EACH DIRECTION    1549 non-null datetime64[ns]
# SECONDARY INCIDENTS START TIMES            73 non-null object
# DIRECTION                                  1618 non-null object
# GEOGRAPHIC                                 839 non-null object
# MP                                         901 non-null object
# TYPE                                       705 non-null object
#  REMARKS / DESCRIPTION                     1628 non-null object
# INCIDENT END TIMES - DIRECTIONAL           1549 non-null object
# SECONDARY INCIDENTS END TIMES              65 non-null object
# Delay Time Total                           1627 non-null object
# WEATHER                                    625 non-null object
# Unnamed: 11                                0 non-null float64
# Unnamed: 12                                24 non-null object
# Unnamed: 13                                0 non-null float64
# Unnamed: 14                                26 non-null object
# dtypes: datetime64[ns](1), float64(2), object(12)
# memory usage: 191.3+ KB

# %%
data.drop(data.columns[[11,12,13,14]], axis=1, inplace=True)

# %%
data.head().T
# Out:
#                                                                                          0  \
# INCIDENT START TIMES FOR EACH DIRECTION                                1992-11-21 12:25:00
# SECONDARY INCIDENTS START TIMES                                                        NaN
# DIRECTION                                                                               WB
# GEOGRAPHIC                                                                             NaN
# MP                                                                                     NaN
# TYPE                                                                                   NaN
#  REMARKS / DESCRIPTION                   MP 56 & 52 TEMP DELAY TO ENABLE SEARCH & RESCU...
# INCIDENT END TIMES - DIRECTIONAL                                       1992-11-21 13:00:00
# SECONDARY INCIDENTS END TIMES                                                          NaN
# Delay Time Total                                                                  00:35:00
# WEATHER                                                                                NaN
#
#                                                                                          1  \
# INCIDENT START TIMES FOR EACH DIRECTION                                1992-11-21 13:13:00
# SECONDARY INCIDENTS START TIMES                                                        NaN
# DIRECTION                                                                               EB
# GEOGRAPHIC                                                                             NaN
# MP                                                                                     NaN
# TYPE                                                                                   NaN
#  REMARKS / DESCRIPTION                   MP 56 & 52 TEMP DELAY TO ENABLE SEARCH & RESCU...
# INCIDENT END TIMES - DIRECTIONAL                                       1992-11-21 14:05:00
# SECONDARY INCIDENTS END TIMES                                                          NaN
# Delay Time Total                                                                  00:52:00
# WEATHER                                                                                NaN
#
#                                                                                          2  \
# INCIDENT START TIMES FOR EACH DIRECTION                                1992-11-21 14:30:00
# SECONDARY INCIDENTS START TIMES                                                        NaN
# DIRECTION                                                                               EB
# GEOGRAPHIC                                                                             NaN
# MP                                                                                     NaN
# TYPE                                                                                   NaN
#  REMARKS / DESCRIPTION                   DELAYS DUE TO SPUNOUT TRUCKS TRAFFIC WORKING T...
# INCIDENT END TIMES - DIRECTIONAL                                       1992-11-21 15:30:00
# SECONDARY INCIDENTS END TIMES                                                          NaN
# Delay Time Total                                                                  01:00:00
# WEATHER                                                                                NaN
#
#                                                                               3  \
# INCIDENT START TIMES FOR EACH DIRECTION                     1992-11-21 14:33:00
# SECONDARY INCIDENTS START TIMES                                             NaN
# DIRECTION                                                                    WB
# GEOGRAPHIC                                                                  NaN
# MP                                                                          NaN
# TYPE                                                                        NaN
#  REMARKS / DESCRIPTION                   LOG TRUCK ACCIDENT LOG BLOCKING LANE 3
# INCIDENT END TIMES - DIRECTIONAL                            1992-11-21 15:30:00
# SECONDARY INCIDENTS END TIMES                                               NaN
# Delay Time Total                                                       00:57:00
# WEATHER                                                                     NaN
#
#                                                                                  4
# INCIDENT START TIMES FOR EACH DIRECTION                        1992-11-30 18:28:00
# SECONDARY INCIDENTS START TIMES                                                NaN
# DIRECTION                                                                       EB
# GEOGRAPHIC                                                                     NaN
# MP                                                                             NaN
# TYPE                                                                           NaN
#  REMARKS / DESCRIPTION                   EB 60 TANKER / CAR COLLISION PT. BLOCKING
# INCIDENT END TIMES - DIRECTIONAL                               1992-11-30 22:10:00
# SECONDARY INCIDENTS END TIMES                                                  NaN
# Delay Time Total                                                          03:42:00
# WEATHER                                                                        NaN

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1632 entries, 0 to 1631
# Data columns (total 11 columns):
# INCIDENT START TIMES FOR EACH DIRECTION    1549 non-null datetime64[ns]
# SECONDARY INCIDENTS START TIMES            73 non-null object
# DIRECTION                                  1618 non-null object
# GEOGRAPHIC                                 839 non-null object
# MP                                         901 non-null object
# TYPE                                       705 non-null object
#  REMARKS / DESCRIPTION                     1628 non-null object
# INCIDENT END TIMES - DIRECTIONAL           1549 non-null object
# SECONDARY INCIDENTS END TIMES              65 non-null object
# Delay Time Total                           1627 non-null object
# WEATHER                                    625 non-null object
# dtypes: datetime64[ns](1), object(10)
# memory usage: 140.3+ KB

# %%
data.tail().T
# Out:
#                                                                                       1627  \
# INCIDENT START TIMES FOR EACH DIRECTION                                2018-03-04 20:31:00
# SECONDARY INCIDENTS START TIMES                                                        NaN
# DIRECTION                                                                               EB
# GEOGRAPHIC                                                                      NORTH BEND
# MP                                                                                      34
# TYPE                                                                           WX/TRACTION
#  REMARKS / DESCRIPTION                   MULTIPLE UNCHAINED & SPUN OUT VEHICLES AND MUL...
# INCIDENT END TIMES - DIRECTIONAL                                       2018-03-05 00:00:00
# SECONDARY INCIDENTS END TIMES                                                          NaN
# Delay Time Total                                                                  03:29:00
# WEATHER                                                                        HEAVY SNOW
#
#                                                                      1628  \
# INCIDENT START TIMES FOR EACH DIRECTION               2018-03-29 09:02:00
# SECONDARY INCIDENTS START TIMES                                       NaN
# DIRECTION                                                              EB
# GEOGRAPHIC                                         NORTH BEND DENNY CREEK
# MP                                                                  34/47
# TYPE                                     SCHEDULED AVALANCHE CONTROL WORK
#  REMARKS / DESCRIPTION                                       TANK MISSION
# INCIDENT END TIMES - DIRECTIONAL                      2018-03-29 09:39:00
# SECONDARY INCIDENTS END TIMES                                         NaN
# Delay Time Total                                                 00:37:00
# WEATHER                                                               FOG
#
#                                                                      1629  \
# INCIDENT START TIMES FOR EACH DIRECTION               2018-03-29 09:02:00
# SECONDARY INCIDENTS START TIMES                                       NaN
# DIRECTION                                                              WB
# GEOGRAPHIC                                                  EASTON, MP 52
# MP                                                                  52/70
# TYPE                                     SCHEDULED AVALANCHE CONTROL WORK
#  REMARKS / DESCRIPTION                                       TANK MISSION
# INCIDENT END TIMES - DIRECTIONAL                      2018-03-29 09:42:00
# SECONDARY INCIDENTS END TIMES                                         NaN
# Delay Time Total                                                 00:40:00
# WEATHER                                                               FOG
#
#                                                                                       1630  \
# INCIDENT START TIMES FOR EACH DIRECTION                                2018-04-01 22:29:00
# SECONDARY INCIDENTS START TIMES                                                        NaN
# DIRECTION                                                                               WB
# GEOGRAPHIC                                           EASTON/GOLD CREEK/CLE ELUM/ELLENSBURG
# MP                                                                            56/70/84/106
# TYPE                                                                           WX/TRACTION
#  REMARKS / DESCRIPTION                   MULTIPLE UNCHAINED & SPUN OUT VEHICLES AND MUL...
# INCIDENT END TIMES - DIRECTIONAL                                       2018-04-02 07:41:00
# SECONDARY INCIDENTS END TIMES                                                          NaN
# Delay Time Total                                                                  09:12:00
# WEATHER                                                                        HEAVY SNOW
#
#                                                                                       1631
# INCIDENT START TIMES FOR EACH DIRECTION                                2018-04-01 23:09:00
# SECONDARY INCIDENTS START TIMES                                                        NaN
# DIRECTION                                                                               EB
# GEOGRAPHIC                                                          NORTH BEND/DENNY CREEK
# MP                                                                                   34/47
# TYPE                                                                           WX/TRACTION
#  REMARKS / DESCRIPTION                   MULTIPLE UNCHAINED & SPUN OUT VEHICLES AND MUL...
# INCIDENT END TIMES - DIRECTIONAL                                       2018-04-02 07:58:00
# SECONDARY INCIDENTS END TIMES                                                          NaN
# Delay Time Total                                                                  08:49:00
# WEATHER                                                                        HEAVY SNOW

# %%
data.drop(data.columns[[1,8]], axis=1, inplace=True)

# %%
data.head(10).T
# Out:
#                                                                                          0  \
# INCIDENT START TIMES FOR EACH DIRECTION                                1992-11-21 12:25:00
# DIRECTION                                                                               WB
# GEOGRAPHIC                                                                             NaN
# MP                                                                                     NaN
# TYPE                                                                                   NaN
#  REMARKS / DESCRIPTION                   MP 56 & 52 TEMP DELAY TO ENABLE SEARCH & RESCU...
# INCIDENT END TIMES - DIRECTIONAL                                       1992-11-21 13:00:00
# Delay Time Total                                                                  00:35:00
# WEATHER                                                                                NaN
#
#                                                                                          1  \
# INCIDENT START TIMES FOR EACH DIRECTION                                1992-11-21 13:13:00
# DIRECTION                                                                               EB
# GEOGRAPHIC                                                                             NaN
# MP                                                                                     NaN
# TYPE                                                                                   NaN
#  REMARKS / DESCRIPTION                   MP 56 & 52 TEMP DELAY TO ENABLE SEARCH & RESCU...
# INCIDENT END TIMES - DIRECTIONAL                                       1992-11-21 14:05:00
# Delay Time Total                                                                  00:52:00
# WEATHER                                                                                NaN
#
#                                                                                          2  \
# INCIDENT START TIMES FOR EACH DIRECTION                                1992-11-21 14:30:00
# DIRECTION                                                                               EB
# GEOGRAPHIC                                                                             NaN
# MP                                                                                     NaN
# TYPE                                                                                   NaN
#  REMARKS / DESCRIPTION                   DELAYS DUE TO SPUNOUT TRUCKS TRAFFIC WORKING T...
# INCIDENT END TIMES - DIRECTIONAL                                       1992-11-21 15:30:00
# Delay Time Total                                                                  01:00:00
# WEATHER                                                                                NaN
#
#                                                                               3  \
# INCIDENT START TIMES FOR EACH DIRECTION                     1992-11-21 14:33:00
# DIRECTION                                                                    WB
# GEOGRAPHIC                                                                  NaN
# MP                                                                          NaN
# TYPE                                                                        NaN
#  REMARKS / DESCRIPTION                   LOG TRUCK ACCIDENT LOG BLOCKING LANE 3
# INCIDENT END TIMES - DIRECTIONAL                            1992-11-21 15:30:00
# Delay Time Total                                                       00:57:00
# WEATHER                                                                     NaN
#
#                                                                                  4  \
# INCIDENT START TIMES FOR EACH DIRECTION                        1992-11-30 18:28:00
# DIRECTION                                                                       EB
# GEOGRAPHIC                                                                     NaN
# MP                                                                             NaN
# TYPE                                                                           NaN
#  REMARKS / DESCRIPTION                   EB 60 TANKER / CAR COLLISION PT. BLOCKING
# INCIDENT END TIMES - DIRECTIONAL                               1992-11-30 22:10:00
# Delay Time Total                                                          03:42:00
# WEATHER                                                                        NaN
#
#                                                                               5  \
# INCIDENT START TIMES FOR EACH DIRECTION                     1992-12-08 05:19:00
# DIRECTION                                                                    EB
# GEOGRAPHIC                                                                  NaN
# MP                                                                          NaN
# TYPE                                                                        NaN
#  REMARKS / DESCRIPTION                   36 LANES BLOCKED DUE TO SPUN OUT SEMIS
# INCIDENT END TIMES - DIRECTIONAL                            1992-12-08 06:06:00
# Delay Time Total                                                       00:47:00
# WEATHER                                                                     NaN
#
#                                                                            6  \
# INCIDENT START TIMES FOR EACH DIRECTION                                  NaT
# DIRECTION                                                                 EB
# GEOGRAPHIC                                                               NaN
# MP                                                                       NaN
# TYPE                                                                     NaN
#  REMARKS / DESCRIPTION                   EB STOPPED AT EDGEWICK DUE TO ABOVE
# INCIDENT END TIMES - DIRECTIONAL                                         NaN
# Delay Time Total                                                    00:00:00
# WEATHER                                                                  NaN
#
#                                                                                 7  \
# INCIDENT START TIMES FOR EACH DIRECTION                       1992-12-08 16:19:00
# DIRECTION                                                                      EB
# GEOGRAPHIC                                                                    NaN
# MP                                                                            NaN
# TYPE                                                                          NaN
#  REMARKS / DESCRIPTION                   47 AVALANCHE CONTROL AIRPLANE CURVE 51.5
# INCIDENT END TIMES - DIRECTIONAL                              1992-12-08 16:40:00
# Delay Time Total                                                         00:21:00
# WEATHER                                                                       NaN
#
#                                                                            8  \
# INCIDENT START TIMES FOR EACH DIRECTION                  1992-12-09 10:28:00
# DIRECTION                                                                 EB
# GEOGRAPHIC                                                               NaN
# MP                                                                       NaN
# TYPE                                                                     NaN
#  REMARKS / DESCRIPTION                   56 AVALANCHE CONTROL EAST SNOW SHED
# INCIDENT END TIMES - DIRECTIONAL                         1992-12-09 10:45:00
# Delay Time Total                                                    00:17:00
# WEATHER                                                                  NaN
#
#                                                                                 9
# INCIDENT START TIMES FOR EACH DIRECTION                       1992-12-10 08:43:00
# DIRECTION                                                                     EB
# GEOGRAPHIC                                                                    NaN
# MP                                                                            NaN
# TYPE                                                                          NaN
#  REMARKS / DESCRIPTION                   47 AVALANCHE CONTROL AIRPLANE CURVE 51.5
# INCIDENT END TIMES - DIRECTIONAL                              1992-12-10 09:22:00
# Delay Time Total                                                         00:39:00
# WEATHER                                                                       NaN

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1632 entries, 0 to 1631
# Data columns (total 9 columns):
# INCIDENT START TIMES FOR EACH DIRECTION    1549 non-null datetime64[ns]
# DIRECTION                                  1618 non-null object
# GEOGRAPHIC                                 839 non-null object
# MP                                         901 non-null object
# TYPE                                       705 non-null object
#  REMARKS / DESCRIPTION                     1628 non-null object
# INCIDENT END TIMES - DIRECTIONAL           1549 non-null object
# Delay Time Total                           1627 non-null object
# WEATHER                                    625 non-null object
# dtypes: datetime64[ns](1), object(8)
# memory usage: 114.8+ KB

# %%
data.tail().T
# Out:
#                                                                                       1627  \
# INCIDENT START TIMES FOR EACH DIRECTION                                2018-03-04 20:31:00
# DIRECTION                                                                               EB
# GEOGRAPHIC                                                                      NORTH BEND
# MP                                                                                      34
# TYPE                                                                           WX/TRACTION
#  REMARKS / DESCRIPTION                   MULTIPLE UNCHAINED & SPUN OUT VEHICLES AND MUL...
# INCIDENT END TIMES - DIRECTIONAL                                       2018-03-05 00:00:00
# Delay Time Total                                                                  03:29:00
# WEATHER                                                                        HEAVY SNOW
#
#                                                                      1628  \
# INCIDENT START TIMES FOR EACH DIRECTION               2018-03-29 09:02:00
# DIRECTION                                                              EB
# GEOGRAPHIC                                         NORTH BEND DENNY CREEK
# MP                                                                  34/47
# TYPE                                     SCHEDULED AVALANCHE CONTROL WORK
#  REMARKS / DESCRIPTION                                       TANK MISSION
# INCIDENT END TIMES - DIRECTIONAL                      2018-03-29 09:39:00
# Delay Time Total                                                 00:37:00
# WEATHER                                                               FOG
#
#                                                                      1629  \
# INCIDENT START TIMES FOR EACH DIRECTION               2018-03-29 09:02:00
# DIRECTION                                                              WB
# GEOGRAPHIC                                                  EASTON, MP 52
# MP                                                                  52/70
# TYPE                                     SCHEDULED AVALANCHE CONTROL WORK
#  REMARKS / DESCRIPTION                                       TANK MISSION
# INCIDENT END TIMES - DIRECTIONAL                      2018-03-29 09:42:00
# Delay Time Total                                                 00:40:00
# WEATHER                                                               FOG
#
#                                                                                       1630  \
# INCIDENT START TIMES FOR EACH DIRECTION                                2018-04-01 22:29:00
# DIRECTION                                                                               WB
# GEOGRAPHIC                                           EASTON/GOLD CREEK/CLE ELUM/ELLENSBURG
# MP                                                                            56/70/84/106
# TYPE                                                                           WX/TRACTION
#  REMARKS / DESCRIPTION                   MULTIPLE UNCHAINED & SPUN OUT VEHICLES AND MUL...
# INCIDENT END TIMES - DIRECTIONAL                                       2018-04-02 07:41:00
# Delay Time Total                                                                  09:12:00
# WEATHER                                                                        HEAVY SNOW
#
#                                                                                       1631
# INCIDENT START TIMES FOR EACH DIRECTION                                2018-04-01 23:09:00
# DIRECTION                                                                               EB
# GEOGRAPHIC                                                          NORTH BEND/DENNY CREEK
# MP                                                                                   34/47
# TYPE                                                                           WX/TRACTION
#  REMARKS / DESCRIPTION                   MULTIPLE UNCHAINED & SPUN OUT VEHICLES AND MUL...
# INCIDENT END TIMES - DIRECTIONAL                                       2018-04-02 07:58:00
# Delay Time Total                                                                  08:49:00
# WEATHER                                                                        HEAVY SNOW

# %%
data.rename(columns={'INCIDENT START TIMES FOR EACH DIRECTION':'date'}, inplace=True)

# %%
data.tail().T
# Out:
#                                                                                1627  \
# date                                                            2018-03-04 20:31:00
# SECONDARY INCIDENTS START TIMES                                                 NaN
# DIRECTION                                                                        EB
# GEOGRAPHIC                                                               NORTH BEND
# MP                                                                               34
# TYPE                                                                    WX/TRACTION
#  REMARKS / DESCRIPTION            MULTIPLE UNCHAINED & SPUN OUT VEHICLES AND MUL...
# INCIDENT END TIMES - DIRECTIONAL                                2018-03-05 00:00:00
# SECONDARY INCIDENTS END TIMES                                                   NaN
# Delay Time Total                                                           03:29:00
# WEATHER                                                                 HEAVY SNOW
#
#                                                               1628  \
# date                                           2018-03-29 09:02:00
# SECONDARY INCIDENTS START TIMES                                NaN
# DIRECTION                                                       EB
# GEOGRAPHIC                                  NORTH BEND DENNY CREEK
# MP                                                           34/47
# TYPE                              SCHEDULED AVALANCHE CONTROL WORK
#  REMARKS / DESCRIPTION                                TANK MISSION
# INCIDENT END TIMES - DIRECTIONAL               2018-03-29 09:39:00
# SECONDARY INCIDENTS END TIMES                                  NaN
# Delay Time Total                                          00:37:00
# WEATHER                                                        FOG
#
#                                                               1629  \
# date                                           2018-03-29 09:02:00
# SECONDARY INCIDENTS START TIMES                                NaN
# DIRECTION                                                       WB
# GEOGRAPHIC                                           EASTON, MP 52
# MP                                                           52/70
# TYPE                              SCHEDULED AVALANCHE CONTROL WORK
#  REMARKS / DESCRIPTION                                TANK MISSION
# INCIDENT END TIMES - DIRECTIONAL               2018-03-29 09:42:00
# SECONDARY INCIDENTS END TIMES                                  NaN
# Delay Time Total                                          00:40:00
# WEATHER                                                        FOG
#
#                                                                                1630  \
# date                                                            2018-04-01 22:29:00
# SECONDARY INCIDENTS START TIMES                                                 NaN
# DIRECTION                                                                        WB
# GEOGRAPHIC                                    EASTON/GOLD CREEK/CLE ELUM/ELLENSBURG
# MP                                                                     56/70/84/106
# TYPE                                                                    WX/TRACTION
#  REMARKS / DESCRIPTION            MULTIPLE UNCHAINED & SPUN OUT VEHICLES AND MUL...
# INCIDENT END TIMES - DIRECTIONAL                                2018-04-02 07:41:00
# SECONDARY INCIDENTS END TIMES                                                   NaN
# Delay Time Total                                                           09:12:00
# WEATHER                                                                 HEAVY SNOW
#
#                                                                                1631
# date                                                            2018-04-01 23:09:00
# SECONDARY INCIDENTS START TIMES                                                 NaN
# DIRECTION                                                                        EB
# GEOGRAPHIC                                                   NORTH BEND/DENNY CREEK
# MP                                                                            34/47
# TYPE                                                                    WX/TRACTION
#  REMARKS / DESCRIPTION            MULTIPLE UNCHAINED & SPUN OUT VEHICLES AND MUL...
# INCIDENT END TIMES - DIRECTIONAL                                2018-04-02 07:58:00
# SECONDARY INCIDENTS END TIMES                                                   NaN
# Delay Time Total                                                           08:49:00
# WEATHER                                                                 HEAVY SNOW

# %%
df = data[(data['date'] > '2006-12-31')]

# %%
df.head().T
# Out:
#                                                                           830  \
# date                                                      2007-01-02 14:31:00
# SECONDARY INCIDENTS START TIMES                                           NaN
# DIRECTION                                                                  EB
# GEOGRAPHIC                                                          Snow Shed
# MP                                                                         58
# TYPE                                                                      NaN
#  REMARKS / DESCRIPTION            Avalanche Control ESS traffic stopped eb 56
# INCIDENT END TIMES - DIRECTIONAL                          2007-01-02 16:45:00
# SECONDARY INCIDENTS END TIMES                                             NaN
# Delay Time Total                                                     02:14:00
# WEATHER                                                               Raining
#
#                                                                           831  \
# date                                                      2007-01-02 15:00:00
# SECONDARY INCIDENTS START TIMES                                           NaN
# DIRECTION                                                                  WB
# GEOGRAPHIC                                                          Snow Shed
# MP                                                                         58
# TYPE                                                                      NaN
#  REMARKS / DESCRIPTION            Avalanche Control ESS traffic stopped wb 61
# INCIDENT END TIMES - DIRECTIONAL                          2007-01-02 15:44:00
# SECONDARY INCIDENTS END TIMES                                             NaN
# Delay Time Total                                                     00:44:00
# WEATHER                                                               Raining
#
#                                                                                832  \
# date                                                           2007-01-02 19:23:00
# SECONDARY INCIDENTS START TIMES                                                NaN
# DIRECTION                                                                       WB
# GEOGRAPHIC                                                               Denny Mt.
# MP                                                                              51
# TYPE                                                                           NaN
#  REMARKS / DESCRIPTION            Avalanche Control MP 51 WB traffic stopped wb 52
# INCIDENT END TIMES - DIRECTIONAL                               2007-01-02 19:33:00
# SECONDARY INCIDENTS END TIMES                                                  NaN
# Delay Time Total                                                          00:10:00
# WEATHER                                                                    Raining
#
#                                                                           833  \
# date                                                      2007-01-03 11:28:00
# SECONDARY INCIDENTS START TIMES                                           NaN
# DIRECTION                                                                  WB
# GEOGRAPHIC                                                          Snow Shed
# MP                                                                         58
# TYPE                                                                      NaN
#  REMARKS / DESCRIPTION            Avalanche Control ESS traffic stopped wb 61
# INCIDENT END TIMES - DIRECTIONAL                          2007-01-03 11:40:00
# SECONDARY INCIDENTS END TIMES                                             NaN
# Delay Time Total                                                     00:12:00
# WEATHER                                                       Mixed rain snow
#
#                                                                           834
# date                                                      2007-01-03 11:29:00
# SECONDARY INCIDENTS START TIMES                                           NaN
# DIRECTION                                                                  EB
# GEOGRAPHIC                                                          Snow Shed
# MP                                                                         58
# TYPE                                                                      NaN
#  REMARKS / DESCRIPTION            Avalanche Control ESS traffic stopped eb 56
# INCIDENT END TIMES - DIRECTIONAL                          2007-01-03 11:46:00
# SECONDARY INCIDENTS END TIMES                                             NaN
# Delay Time Total                                                     00:17:00
# WEATHER                                                       Mixed rain snow

# %%
df.WEATHER.unique()
# Out:
# array(['Raining', 'Mixed rain snow', 'snowing', 'snowing ', 'heavy snow',
#        'sn / rn heavy windy', 'heavy rain windy',
#        'icy, windy blowing snow', 'clear', nan,
#        'snowing heavy snow on roadway ', 'scattered slush places',
#        'occ. Snow snow and ice', 'heavy snow squalls', 'light snow',
#        'snowing snow and slush', 'pt. cloudy bare and wet',
#        'raining bare and wet', 'raining heavy', 'snowing heavy',
#        'Rn Sn mixed', 'SNOWING', 'lt. snow shrs.', 'snow showers',
#        'Clear', 'SNOWING & BLOWING', 'Snowing', 'lt. snow',
#        'Heavy Snowfall ', 'Hevy Snowfall', 'raining', 'Very heavy rain',
#        'overcast', 'sno showers', 'snowing poor visibility', 'RAINING',
#        'Snowing heavy', 'SNOWING HEAVY', ' SNOWING / BLOWING', 'SNOWING ',
#        'CLEAR', 'Mixed Rain / Snow', 'LIGHT RAIN',
#        'HEAVY RAIN TO HEAVY SNOW', 'LIGHT SNOW', 'OCC. SNOW', 'OVERCAST',
#        'RAIN/SNO MIX  STRONG WINDS', 'HEAVY RAIN FOLLOWING HEAVY SNOW',
#        'MIXED RAIN/SNOW', 'HEAVY RAIN ', 'HEAVY SNOW SHOWERS',
#        'FREEZING RAIN', 'FAIR', 'SNOWING HEAVILY', 'SNOWING HARD ',
#        'FLURRIES ', 'SCATTERED CLOUDS', 'BROKEN CLOUDS', 'PARTLY CLOUDY',
#        'RAINING LIGHTLY', 'RAINING   ', 'RAINING ', 'SNOWING LIGHTLY',
#        'CLEAR PATCHY FOG', 'HEAVY CONVERGENCE ZONE  SNOWING HEAVILY ',
#        'SNOWING LIGHT', 'RAIN / SLEET', 'SNOW/FRZ RAIN',
#        'OVERCAST GUSTY WINDS', 'MODERATE TO HEAVY FREEZING RAIN',
#        'HEAVY SNOW', 'HEAVY SNOW TO FREEZING RAIN / SLEET',
#        'SNOW TO RAIN', 'RAIN', 'snow', 'HEAVY WET SNOW',
#        'OVERCAST OCCASIONAL RAIN', 'SNOWING HARD', 'HEAVY SNOW ', 'FOG'],
#       dtype=object)

# %%
df.tail().T
# Out:
#                                                                                1627  \
# date                                                            2018-03-04 20:31:00
# SECONDARY INCIDENTS START TIMES                                                 NaN
# DIRECTION                                                                        EB
# GEOGRAPHIC                                                               NORTH BEND
# MP                                                                               34
# TYPE                                                                    WX/TRACTION
#  REMARKS / DESCRIPTION            MULTIPLE UNCHAINED & SPUN OUT VEHICLES AND MUL...
# INCIDENT END TIMES - DIRECTIONAL                                2018-03-05 00:00:00
# SECONDARY INCIDENTS END TIMES                                                   NaN
# Delay Time Total                                                           03:29:00
# WEATHER                                                                 HEAVY SNOW
#
#                                                               1628  \
# date                                           2018-03-29 09:02:00
# SECONDARY INCIDENTS START TIMES                                NaN
# DIRECTION                                                       EB
# GEOGRAPHIC                                  NORTH BEND DENNY CREEK
# MP                                                           34/47
# TYPE                              SCHEDULED AVALANCHE CONTROL WORK
#  REMARKS / DESCRIPTION                                TANK MISSION
# INCIDENT END TIMES - DIRECTIONAL               2018-03-29 09:39:00
# SECONDARY INCIDENTS END TIMES                                  NaN
# Delay Time Total                                          00:37:00
# WEATHER                                                        FOG
#
#                                                               1629  \
# date                                           2018-03-29 09:02:00
# SECONDARY INCIDENTS START TIMES                                NaN
# DIRECTION                                                       WB
# GEOGRAPHIC                                           EASTON, MP 52
# MP                                                           52/70
# TYPE                              SCHEDULED AVALANCHE CONTROL WORK
#  REMARKS / DESCRIPTION                                TANK MISSION
# INCIDENT END TIMES - DIRECTIONAL               2018-03-29 09:42:00
# SECONDARY INCIDENTS END TIMES                                  NaN
# Delay Time Total                                          00:40:00
# WEATHER                                                        FOG
#
#                                                                                1630  \
# date                                                            2018-04-01 22:29:00
# SECONDARY INCIDENTS START TIMES                                                 NaN
# DIRECTION                                                                        WB
# GEOGRAPHIC                                    EASTON/GOLD CREEK/CLE ELUM/ELLENSBURG
# MP                                                                     56/70/84/106
# TYPE                                                                    WX/TRACTION
#  REMARKS / DESCRIPTION            MULTIPLE UNCHAINED & SPUN OUT VEHICLES AND MUL...
# INCIDENT END TIMES - DIRECTIONAL                                2018-04-02 07:41:00
# SECONDARY INCIDENTS END TIMES                                                   NaN
# Delay Time Total                                                           09:12:00
# WEATHER                                                                 HEAVY SNOW
#
#                                                                                1631
# date                                                            2018-04-01 23:09:00
# SECONDARY INCIDENTS START TIMES                                                 NaN
# DIRECTION                                                                        EB
# GEOGRAPHIC                                                   NORTH BEND/DENNY CREEK
# MP                                                                            34/47
# TYPE                                                                    WX/TRACTION
#  REMARKS / DESCRIPTION            MULTIPLE UNCHAINED & SPUN OUT VEHICLES AND MUL...
# INCIDENT END TIMES - DIRECTIONAL                                2018-04-02 07:58:00
# SECONDARY INCIDENTS END TIMES                                                   NaN
# Delay Time Total                                                           08:49:00
# WEATHER                                                                 HEAVY SNOW

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 776 entries, 830 to 1631
# Data columns (total 11 columns):
# date                                776 non-null datetime64[ns]
# SECONDARY INCIDENTS START TIMES     2 non-null object
# DIRECTION                           776 non-null object
# GEOGRAPHIC                          711 non-null object
# MP                                  763 non-null object
# TYPE                                696 non-null object
#  REMARKS / DESCRIPTION              774 non-null object
# INCIDENT END TIMES - DIRECTIONAL    775 non-null object
# SECONDARY INCIDENTS END TIMES       3 non-null object
# Delay Time Total                    775 non-null object
# WEATHER                             590 non-null object
# dtypes: datetime64[ns](1), object(10)
# memory usage: 72.8+ KB

# %%
westbound = pd.Series([True if value == 'WB' else False for value in df.DIRECTION])

# %%
westbound
# Out:
# 0      False
# 1       True
# 2       True
# 3       True
# 4      False
# 5      False
# 6       True
# 7      False
# 8       True
# 9      False
# 10      True
# 11     False
# 12      True
# 13     False
# 14     False
# 15      True
# 16     False
# 17      True
# 18     False
# 19      True
# 20     False
# 21      True
# 22     False
# 23      True
# 24     False
# 25     False
# 26      True
# 27     False
# 28      True
# 29     False
#        ...
# 745     True
# 746     True
# 747    False
# 748     True
# 749    False
# 750    False
# 751    False
# 752    False
# 753    False
# 754    False
# 755    False
# 756     True
# 757    False
# 758    False
# 759    False
# 760     True
# 761    False
# 762    False
# 763     True
# 764    False
# 765     True
# 766     True
# 767    False
# 768    False
# 769     True
# 770    False
# 771    False
# 772     True
# 773     True
# 774    False
# Length: 775, dtype: bool

# %%
df.rename(columns={'Delay Time Total':'delay'}, inplace=True)
# Out:
# /Users/leanne/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py:3781: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   return super(DataFrame, self).rename(**kwargs)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 776 entries, 830 to 1631
# Data columns (total 11 columns):
# date                                776 non-null datetime64[ns]
# SECONDARY INCIDENTS START TIMES     2 non-null object
# DIRECTION                           776 non-null object
# GEOGRAPHIC                          711 non-null object
# MP                                  763 non-null object
# TYPE                                696 non-null object
#  REMARKS / DESCRIPTION              774 non-null object
# INCIDENT END TIMES - DIRECTIONAL    775 non-null object
# SECONDARY INCIDENTS END TIMES       3 non-null object
# delay                               775 non-null object
# WEATHER                             590 non-null object
# dtypes: datetime64[ns](1), object(10)
# memory usage: 72.8+ KB

# %%
df.delay.unique()
# Out:
# array([datetime.time(2, 14), datetime.time(0, 44), datetime.time(0, 10),
#        datetime.time(0, 12), datetime.time(0, 17), datetime.time(0, 15),
#        datetime.time(0, 9), datetime.time(0, 22), datetime.time(0, 20),
#        datetime.time(0, 16), datetime.time(1, 13), datetime.time(0, 38),
#        datetime.time(2, 0), datetime.time(2, 12), datetime.time(2, 7),
#        datetime.time(0, 54), datetime.time(0, 26), datetime.time(2, 15),
#        datetime.time(3, 29), datetime.time(0, 35), datetime.time(0, 18),
#        datetime.time(5, 17), datetime.time(0, 13), datetime.time(0, 25),
#        nan, datetime.time(0, 42), datetime.time(1, 18),
#        datetime.time(2, 45), datetime.time(0, 7), datetime.time(0, 29),
#        datetime.time(6, 44), datetime.time(4, 7), datetime.time(0, 14),
#        datetime.time(0, 23), datetime.time(0, 27), datetime.time(0, 19),
#        datetime.time(0, 6), datetime.time(1, 54), datetime.time(4, 53),
#        datetime.time(0, 43), datetime.time(3, 53), datetime.time(4, 47),
#        datetime.time(2, 37), datetime.time(5, 50), datetime.time(6, 28),
#        datetime.time(1, 20), datetime.time(1, 30), datetime.time(1, 25),
#        datetime.time(1, 6), datetime.time(1, 4), datetime.time(0, 57),
#        datetime.time(3, 47), datetime.time(1, 0), datetime.time(1, 1),
#        datetime.time(3, 0), datetime.time(4, 25), datetime.time(1, 15),
#        datetime.time(0, 40), datetime.time(0, 45), datetime.time(1, 45),
#        datetime.time(0, 30), datetime.time(0, 50), datetime.time(1, 10),
#        datetime.time(0, 41), datetime.time(0, 32), datetime.time(0, 11),
#        datetime.time(1, 49), datetime.time(0, 46), datetime.time(0, 49),
#        datetime.time(1, 34), datetime.time(0, 37), datetime.time(3, 36),
#        datetime.time(1, 8), datetime.time(1, 48), datetime.time(0, 24),
#        datetime.time(0, 21), datetime.time(1, 24),
#        datetime.datetime(1900, 1, 1, 3, 36),
#        datetime.datetime(1900, 1, 2, 13, 23),
#        datetime.datetime(1900, 1, 2, 11, 46), datetime.time(0, 39),
#        datetime.time(5, 2), datetime.time(4, 34), datetime.time(0, 31),
#        datetime.time(8, 20), datetime.time(9, 12),
#        datetime.datetime(1900, 1, 1, 13, 17),
#        datetime.datetime(1900, 1, 1, 12, 42), datetime.time(5, 1),
#        datetime.time(0, 53), datetime.time(1, 3), datetime.time(0, 55),
#        datetime.time(0, 33), datetime.time(0, 51), datetime.time(0, 28),
#        datetime.time(1, 35), datetime.time(2, 17), datetime.time(2, 39),
#        datetime.time(2, 2), datetime.time(1, 53), datetime.time(1, 36),
#        datetime.time(2, 24), datetime.datetime(2008, 4, 30, 11, 15),
#        datetime.time(13, 24), datetime.time(0, 48), datetime.time(1, 46),
#        datetime.time(13, 55), datetime.time(21, 10),
#        datetime.time(15, 25), datetime.datetime(1900, 1, 2, 9, 10),
#        datetime.datetime(1900, 1, 2, 11, 50), datetime.time(1, 57),
#        datetime.time(1, 37), datetime.time(0, 8), datetime.time(2, 8),
#        datetime.time(0, 47), datetime.time(2, 54), datetime.time(0, 34),
#        datetime.time(1, 5), datetime.time(2, 11), datetime.time(1, 12),
#        datetime.time(0, 36), datetime.time(1, 14), datetime.time(1, 41),
#        datetime.time(0, 3), datetime.time(3, 45), datetime.time(4, 0),
#        datetime.time(1, 22), datetime.time(3, 15), datetime.time(1, 7),
#        datetime.time(8, 38), datetime.time(5, 34), datetime.time(0, 52),
#        datetime.time(0, 59), datetime.time(4, 35), datetime.time(3, 19),
#        datetime.time(1, 55), datetime.time(1, 21), datetime.time(4, 22),
#        datetime.time(3, 24), datetime.time(1, 31), datetime.time(1, 51),
#        datetime.time(2, 27), datetime.time(1, 59), datetime.time(1, 26),
#        datetime.time(1, 33), datetime.time(2, 32), datetime.time(7, 0),
#        datetime.time(10, 4), datetime.time(9, 7), datetime.time(0, 58),
#        datetime.time(2, 13), datetime.time(10, 54), datetime.time(1, 2),
#        datetime.time(4, 39), datetime.time(3, 1), datetime.time(0, 56),
#        datetime.time(2, 33), datetime.time(3, 20), datetime.time(5, 35),
#        datetime.time(5, 45), datetime.time(2, 19), datetime.time(1, 11),
#        datetime.time(1, 9), datetime.time(4, 57), datetime.time(4, 41),
#        datetime.time(4, 18), datetime.time(1, 16), datetime.time(2, 10),
#        datetime.datetime(1900, 10, 30, 0, 27),
#        datetime.datetime(1900, 10, 30, 0, 43), datetime.time(1, 23),
#        datetime.time(6, 45), datetime.time(3, 14), datetime.time(8, 34),
#        datetime.time(7, 1), datetime.time(7, 12), datetime.time(1, 17),
#        datetime.time(1, 39), datetime.time(18, 8), datetime.time(15, 49),
#        datetime.time(2, 48), datetime.time(11, 11), datetime.time(5, 0),
#        datetime.time(1, 32), datetime.time(9, 20), datetime.time(2, 1),
#        datetime.time(10, 29), datetime.time(1, 42), datetime.time(2, 40),
#        datetime.time(1, 27), datetime.time(2, 21), datetime.time(4, 45),
#        datetime.time(2, 46), datetime.time(10, 43),
#        datetime.datetime(1900, 1, 1, 1, 4),
#        datetime.datetime(1900, 1, 1, 6, 49), datetime.time(2, 4),
#        datetime.time(11, 48), datetime.time(2, 50), datetime.time(2, 3),
#        datetime.time(2, 18), datetime.time(15, 0), datetime.time(5, 48),
#        datetime.time(4, 26), datetime.time(2, 38), datetime.time(3, 52),
#        datetime.time(3, 40), datetime.time(3, 56), datetime.time(4, 27),
#        datetime.time(3, 44), datetime.time(3, 42), datetime.time(8, 43),
#        datetime.time(1, 50), datetime.time(7, 36), datetime.time(4, 33),
#        datetime.time(2, 36), datetime.datetime(1900, 1, 1, 22, 56),
#        datetime.time(2, 31), datetime.datetime(1900, 1, 1, 13, 50),
#        datetime.time(2, 49), datetime.time(9, 34), datetime.time(8, 45),
#        datetime.datetime(1900, 1, 1, 4, 44),
#        datetime.datetime(1900, 1, 1, 14, 42), datetime.time(1, 52),
#        datetime.time(6, 54), datetime.time(6, 55), datetime.time(4, 30),
#        datetime.time(5, 14), datetime.time(3, 48), datetime.time(4, 29),
#        datetime.time(7, 29), datetime.time(7, 3), datetime.time(7, 33),
#        datetime.time(4, 8), datetime.time(4, 14), datetime.time(3, 33),
#        datetime.time(3, 2), datetime.time(7, 6), datetime.time(2, 6),
#        datetime.time(1, 40), datetime.time(5, 58), datetime.time(5, 39),
#        datetime.time(8, 49)], dtype=object)

# %%
df = df.dropna(subset=['delay'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 775 entries, 830 to 1631
# Data columns (total 11 columns):
# date                                775 non-null datetime64[ns]
# SECONDARY INCIDENTS START TIMES     2 non-null object
# DIRECTION                           775 non-null object
# GEOGRAPHIC                          710 non-null object
# MP                                  762 non-null object
# TYPE                                696 non-null object
#  REMARKS / DESCRIPTION              773 non-null object
# INCIDENT END TIMES - DIRECTIONAL    774 non-null object
# SECONDARY INCIDENTS END TIMES       3 non-null object
# delay                               775 non-null object
# WEATHER                             590 non-null object
# dtypes: datetime64[ns](1), object(10)
# memory usage: 72.7+ KB

# %%
snow = df.WEATHER.str.contains('sn', case=False, na=False, regex=True)

# %%
snow.unique()
# Out:
# array([False,  True])

# %%
snow
# Out:
# 830     False
# 831     False
# 832     False
# 833      True
# 834      True
# 835      True
# 836      True
# 837      True
# 838      True
# 839      True
# 840      True
# 841      True
# 842      True
# 843      True
# 846      True
# 847      True
# 848      True
# 851      True
# 852     False
# 853      True
# 861      True
# 862      True
# 863      True
# 864      True
# 865     False
# 866     False
# 869     False
# 870     False
# 872     False
# 873     False
#         ...
# 1602     True
# 1603     True
# 1604     True
# 1605     True
# 1606     True
# 1607     True
# 1608     True
# 1609     True
# 1610     True
# 1611     True
# 1612     True
# 1613     True
# 1614     True
# 1615    False
# 1616    False
# 1617    False
# 1618     True
# 1619     True
# 1620     True
# 1621     True
# 1622     True
# 1623     True
# 1624     True
# 1625     True
# 1626     True
# 1627     True
# 1628    False
# 1629    False
# 1630     True
# 1631     True
# Name: WEATHER, Length: 775, dtype: bool

# %%
df
# Out:
#                     date SECONDARY INCIDENTS START TIMES DIRECTION  \
# 830  2007-01-02 14:31:00                             NaN        EB
# 831  2007-01-02 15:00:00                             NaN        WB
# 832  2007-01-02 19:23:00                             NaN        WB
# 833  2007-01-03 11:28:00                             NaN        WB
# 834  2007-01-03 11:29:00                             NaN        EB
# 835  2007-01-05 00:01:00                             NaN        EB
# 836  2007-01-05 00:02:00                             NaN        WB
# 837  2007-01-05 19:29:00                             NaN        EB
# 838  2007-01-05 19:29:00                             NaN        WB
# 839  2007-01-06 00:26:00                             NaN        EB
# 840  2007-01-06 00:25:00                             NaN        WB
# 841  2007-01-06 03:42:00                             NaN        EB
# 842  2007-01-06 03:43:00                             NaN        WB
# 843  2007-01-07 08:46:00                             NaN        EB
# 846  2007-01-07 12:05:00                             NaN        EB
# 847  2007-01-07 12:10:00                             NaN        WB
# 848  2007-01-07 13:23:00                             NaN        EB
# 851  2007-01-07 17:12:00             2007-01-07 17:12:00        WB
# 852  2007-01-07 20:02:00                             NaN        EB
# 853  2007-01-16 10:12:00                             NaN        WB
# 861  2007-01-18 20:27:00                             NaN        EB
# 862  2007-01-18 20:29:00                             NaN        WB
# 863  2007-01-20 14:00:00                             NaN        EB
# 864  2007-01-20 14:00:00                             NaN        WB
# 865  2007-01-26 15:02:00                             NaN        EB
# 866  2007-01-31 10:17:00                             NaN        EB
# 869  2007-02-05 22:33:00                             NaN        WB
# 870  2007-02-05 22:28:00                             NaN        EB
# 872  2007-02-20 08:15:00                             NaN        WB
# 873  2007-02-20 08:17:00                             NaN        EB
# ...                  ...                             ...       ...
# 1602 2017-11-03 17:23:00                             NaN        WB
# 1603 2017-11-05 11:12:00                             NaN        WB
# 1604 2017-11-05 11:29:00                             NaN        EB
# 1605 2017-11-19 20:05:00                             NaN        WB
# 1606 2017-12-19 07:56:00                             NaN        EB
# 1607 2017-12-19 10:50:00                             NaN        EB
# 1608 2018-01-11 06:58:00                             NaN        EB
# 1609 2018-01-11 10:19:00                             NaN        EB
# 1610 2018-01-11 12:44:00                     OCCASIONALY        EB
# 1611 2018-01-23 17:54:00                             NaN        EB
# 1612 2018-01-26 10:33:00                             NaN        EB
# 1613 2018-01-26 11:10:00                             NaN        WB
# 1614 2018-01-27 04:30:00                             NaN        EB
# 1615 2018-01-27 20:54:00                             NaN        EB
# 1616 2018-02-02 02:00:00                             NaN        EB
# 1617 2018-02-02 02:10:00                             NaN        WB
# 1618 2018-02-16 06:28:00                             NaN        EB
# 1619 2018-02-17 09:17:00                             NaN        EB
# 1620 2018-02-17 12:03:00                             NaN        WB
# 1621 2018-02-18 18:43:00                             NaN       WB
# 1622 2018-03-04 11:27:00                             NaN        WB
# 1623 2018-03-04 12:13:00                             NaN        WB
# 1624 2018-03-04 11:36:00                             NaN        EB
# 1625 2018-03-04 18:02:00                             NaN        EB
# 1626 2018-03-04 18:21:00                             NaN        WB
# 1627 2018-03-04 20:31:00                             NaN        EB
# 1628 2018-03-29 09:02:00                             NaN        EB
# 1629 2018-03-29 09:02:00                             NaN        WB
# 1630 2018-04-01 22:29:00                             NaN        WB
# 1631 2018-04-01 23:09:00                             NaN        EB
#
#                                  GEOGRAPHIC            MP  \
# 830                               Snow Shed            58
# 831                               Snow Shed            58
# 832                               Denny Mt.            51
# 833                               Snow Shed            58
# 834                               Snow Shed            58
# 835                               Snow Shed            58
# 836                               Snow Shed            58
# 837                               Snow Shed            58
# 838                               Snow Shed            58
# 839                               Snow Shed            58
# 840                               Snow Shed            58
# 841                               Snow Shed            58
# 842                               Snow Shed            58
# 843                             Denny Creek       49 - 50
# 846                               Snow Shed            58
# 847                               Snow Shed            58
# 848                               Snow Shed            58
# 851                               Denny Mt.            51
# 852                          Airplane curve            50
# 853                         Top 6-mile hill       35 - 36
# 861                               Snow Shed            58
# 862                               Snow Shed            58
# 863                               Snow Shed            58
# 864                               Snow Shed            58
# 865                               Snow Shed            58
# 866                               Snow Shed            58
# 869                               Snow Shed            58
# 870                               Snow Shed            58
# 872                               Snow Shed           NaN
# 873                               Snow Shed           NaN
# ...                                     ...           ...
# 1602                                 EASTON            71
# 1603                                 EASTON     71,84,106
# 1604                 DENNY CREEK NORTHBEND          34,47
# 1605                                 EASTON            70
# 1606                           DENNY CREEK             47
# 1607                            DENNY CREEK            47
# 1608                            DENNY CREEK            47
# 1609                           WEST BANDERA            45
# 1610                           WEST BANDERA            45
# 1611                           WEST BANDERA            45
# 1612               DENNY CREEK/EAST BANDERA            47
# 1613                                 EASTON            70
# 1614                            DENNY CREEK            47
# 1615                            DENNY CREEK            47
# 1616                             GOLD CREEK            56
# 1617                            PRICE CREEK            62
# 1618                            DENNY CREEK            47
# 1619                            DENNY CREEK            47
# 1620                              DENNY MTN            52
# 1621                      EASTON/GOLD CREEK         70/57
# 1622                             GOLD CREEK            56
# 1623                      EASTON/GOLD CREEK            70
# 1624                            DENNY CREEK            47
# 1625                            DENNY CREEK            47
# 1626                      EASTON/GOLD CREEK         56/70
# 1627                             NORTH BEND            34
# 1628                 NORTH BEND DENNY CREEK         34/47
# 1629                          EASTON, MP 52         52/70
# 1630  EASTON/GOLD CREEK/CLE ELUM/ELLENSBURG  56/70/84/106
# 1631                 NORTH BEND/DENNY CREEK         34/47
#
#                                   TYPE  \
# 830                                NaN
# 831                                NaN
# 832                                NaN
# 833                                NaN
# 834                                NaN
# 835                                NaN
# 836                                NaN
# 837                                NaN
# 838                                NaN
# 839                                NaN
# 840                                NaN
# 841                                NaN
# 842                                NaN
# 843                                NaN
# 846                                NaN
# 847                                NaN
# 848                                NaN
# 851                                NaN
# 852                                NaN
# 853                                NaN
# 861                                NaN
# 862                                NaN
# 863                                NaN
# 864                                NaN
# 865                                NaN
# 866                                NaN
# 869                                NaN
# 870                                NaN
# 872                                NaN
# 873                                NaN
# ...                                ...
# 1602                         COLLISION
# 1603                         COLLISION
# 1604                       WX/TRACTION
# 1605                       WX/TRACTION
# 1606                       WX/TRACTION
# 1607                       WX/TRACTION
# 1608                       WX/TRACTION
# 1609                       WX/TRACTION
# 1610                       WX/TRACTION
# 1611                       WX/TRACTION
# 1612                       WX/TRACTION
# 1613                         COLLISION
# 1614       SCHEDULED AVALANCHE CONTROL
# 1615                         COLLISION
# 1616          ADVANCE NOTICE TEMPORARY
# 1617          ADVANCE NOTICE TEMPORARY
# 1618                       WX/TRACTION
# 1619                       WX/TRACTION
# 1620       SCHEDULED AVALANCHE CONTROL
# 1621                        COLLISIONS
# 1622                       WX/TRACTION
# 1623                       WX/TRACTION
# 1624                       WX/TRACTION
# 1625                       WX/TRACTION
# 1626                       WX/TRACTION
# 1627                       WX/TRACTION
# 1628  SCHEDULED AVALANCHE CONTROL WORK
# 1629  SCHEDULED AVALANCHE CONTROL WORK
# 1630                       WX/TRACTION
# 1631                       WX/TRACTION
#
#                                   REMARKS / DESCRIPTION  \
# 830         Avalanche Control ESS traffic stopped eb 56
# 831         Avalanche Control ESS traffic stopped wb 61
# 832    Avalanche Control MP 51 WB traffic stopped wb 52
# 833         Avalanche Control ESS traffic stopped wb 61
# 834         Avalanche Control ESS traffic stopped eb 56
# 835         Avalanche Control ESS traffic stopped eb 56
# 836         Avalanche Control ESS traffic stopped wb 61
# 837         Avalanche Control ESS traffic stopped eb 56
# 838         Avalanche Control ESS traffic stopped wb 61
# 839         Avalanche Control ESS traffic stopped eb 56
# 840         Avalanche Control ESS traffic stopped wb 61
# 841         Avalanche Control ESS traffic stopped eb 56
# 842         Avalanche Control ESS traffic stopped wb 61
# 843                      Spinouts veh. Losing traction
# 846         Avalanche Control ESS traffic stopped eb 56
# 847         Avalanche Control ESS traffic stopped wb 61
# 848   Avalanche Control ESS traffic stopped eb 47 du...
# 851    Avalanche Control MP 51 WB traffic stopped wb 52
# 852                    Avalanche Control Stopped eb  47
# 853   Multi vehicle collisions - trucks / cars block...
# 861         Avalanche Control ESS traffic stopped eb 56
# 862         Avalanche Control ESS traffic stopped wb 61
# 863         Avalanche Control ESS traffic stopped eb 56
# 864         Avalanche Control ESS traffic stopped wb 61
# 865                   Reroute oversize load around shed
# 866   Stopping traffic 10 min. intervals at the snow...
# 869   blasting to control stray ice fall off the Sno...
# 870   blasting to control stray ice fall off the Sno...
# 872         Avalanche Control ESS traffic stopped wb 61
# 873         Avalanche Control ESS traffic stopped eb 56
# ...                                                 ...
# 1602  BLOCKING COLLISION BIG BRIDGE ALL LANES BLOCKE...
# 1603  MULTIPLE COLLIISIONS, SEMI ROLLOVER,   ALL LAN...
# 1604  TO CLEAR VEHICLES LOSING TRACTION BLOCKING LAN...
# 1605                         TO CLEAR MULTIPLE SPINOUTS
# 1606  TO CLEAR VEHICLES LOSING TRACTION BLOCKING LAN...
# 1607  TO CLEAR VEHICLES LOSING TRACTION BLOCKING LAN...
# 1608             MULTIPLE UNCHAINED & SPUN OUT VEHICLES
# 1609             MULTIPLE UNCHAINED & SPUN OUT VEHICLES
# 1610                        UNCHAINED JACK KNIFFED SEMI
# 1611             MULTIPLE UNCHAINED & SPUN OUT VEHICLES
# 1612             MULTIPLE UNCHAINED & SPUN OUT VEHICLES
# 1613  VEHICLE COLLISIONS & VEHICLES CHAINING IN ROADWAY
# 1614                             AVALANCHE CONTROL WORK
# 1615  MULTIPLE CAR COLLISION BLOCKING ALL LANES MP 6...
# 1616               TO CLEAN SNOW OFF OF WILDLIFE TUNNEL
# 1617               TO CLEAN SNOW OFF OF WILDLIFE TUNNEL
# 1618             MULTIPLE UNCHAINED & SPUN OUT VEHICLES
# 1619             MULTIPLE UNCHAINED & SPUN OUT VEHICLES
# 1620                             AVALANCHE CONTROL WORK
# 1621  MULTIPLE CAR COLLISIONS BLOCKING ALL LANES WES...
# 1622  MULTIPLE UNCHAINED & SPUN OUT VEHICLES AND MUL...
# 1623  MULTIPLE UNCHAINED & SPUN OUT VEHICLES AND MUL...
# 1624  MULTIPLE UNCHAINED & SPUN OUT VEHICLES AND MUL...
# 1625  MULTIPLE UNCHAINED & SPUN OUT VEHICLES AND MUL...
# 1626  MULTIPLE UNCHAINED & SPUN OUT VEHICLES AND MUL...
# 1627  MULTIPLE UNCHAINED & SPUN OUT VEHICLES AND MUL...
# 1628                                       TANK MISSION
# 1629                                       TANK MISSION
# 1630  MULTIPLE UNCHAINED & SPUN OUT VEHICLES AND MUL...
# 1631  MULTIPLE UNCHAINED & SPUN OUT VEHICLES AND MUL...
#
#      INCIDENT END TIMES - DIRECTIONAL SECONDARY INCIDENTS END TIMES     delay  \
# 830               2007-01-02 16:45:00                           NaN  02:14:00
# 831               2007-01-02 15:44:00                           NaN  00:44:00
# 832               2007-01-02 19:33:00                           NaN  00:10:00
# 833               2007-01-03 11:40:00                           NaN  00:12:00
# 834               2007-01-03 11:46:00                           NaN  00:17:00
# 835               2007-01-05 00:16:00                           NaN  00:15:00
# 836               2007-01-05 00:11:00                           NaN  00:09:00
# 837               2007-01-05 19:51:00                           NaN  00:22:00
# 838               2007-01-05 19:44:00                           NaN  00:15:00
# 839               2007-01-06 00:46:00                           NaN  00:20:00
# 840               2007-01-06 00:41:00                           NaN  00:16:00
# 841               2007-01-06 04:55:00                           NaN  01:13:00
# 842               2007-01-06 04:21:00                           NaN  00:38:00
# 843               2007-01-07 10:46:00                           NaN  02:00:00
# 846               2007-01-07 14:17:00                           NaN  02:12:00
# 847               2007-01-07 14:17:00                           NaN  02:07:00
# 848               2007-01-07 14:17:00                           NaN  00:54:00
# 851               2007-01-07 17:38:00                           NaN  00:26:00
# 852               2007-01-07 22:17:00                           NaN  02:15:00
# 853               2007-01-16 13:41:00                           NaN  03:29:00
# 861               2007-01-18 20:43:00                           NaN  00:16:00
# 862               2007-01-18 21:04:00                           NaN  00:35:00
# 863               2007-01-20 14:18:00                           NaN  00:18:00
# 864               2007-01-20 14:18:00                           NaN  00:18:00
# 865               2007-01-26 15:19:00                           NaN  00:17:00
# 866               2007-01-31 15:34:00                           NaN  05:17:00
# 869               2007-02-05 22:46:00                           NaN  00:13:00
# 870               2007-02-05 22:53:00                           NaN  00:25:00
# 872               2007-02-20 08:53:00                           NaN  00:38:00
# 873               2007-02-20 08:59:00                           NaN  00:42:00
# ...                               ...                           ...       ...
# 1602              2017-11-03 21:37:00                           NaN  04:14:00
# 1603              2017-11-05 14:45:00                           NaN  03:33:00
# 1604              2017-11-05 14:31:00                           NaN  03:02:00
# 1605              2017-11-19 22:32:00                           NaN  02:27:00
# 1606              2017-12-19 10:03:00                           NaN  02:07:00
# 1607              2017-12-19 12:25:00                           NaN  01:35:00
# 1608              2018-01-11 08:18:00                           NaN  01:20:00
# 1609              2018-01-11 11:39:00                           NaN  01:20:00
# 1610              2018-01-11 19:50:00                           NaN  07:06:00
# 1611              2018-01-23 20:02:00                           NaN  02:08:00
# 1612              2018-01-26 12:39:00                           NaN  02:06:00
# 1613              2018-01-26 12:50:00                           NaN  01:40:00
# 1614              2018-01-27 05:15:00                           NaN  00:45:00
# 1615              2018-01-27 21:45:00                           NaN  00:51:00
# 1616              2018-02-02 02:30:00                      02:35:00  00:30:00
# 1617              2018-02-02 02:34:00                      02:39:00  00:24:00
# 1618              2018-02-16 08:40:00                           NaN  02:12:00
# 1619              2018-02-17 09:55:00                           NaN  00:38:00
# 1620              2018-02-17 12:34:00                           NaN  00:31:00
# 1621              2018-02-18 20:13:00                           NaN  01:30:00
# 1622              2018-03-04 13:45:00                           NaN  02:18:00
# 1623              2018-03-04 13:45:00                           NaN  01:32:00
# 1624              2018-03-04 13:49:00                           NaN  02:13:00
# 1625              2018-03-05 00:00:00                           NaN  05:58:00
# 1626              2018-03-05 00:00:00                           NaN  05:39:00
# 1627              2018-03-05 00:00:00                           NaN  03:29:00
# 1628              2018-03-29 09:39:00                           NaN  00:37:00
# 1629              2018-03-29 09:42:00                           NaN  00:40:00
# 1630              2018-04-02 07:41:00                           NaN  09:12:00
# 1631              2018-04-02 07:58:00                           NaN  08:49:00
#
#                        WEATHER
# 830                    Raining
# 831                    Raining
# 832                    Raining
# 833            Mixed rain snow
# 834            Mixed rain snow
# 835                    snowing
# 836                   snowing
# 837                    snowing
# 838                   snowing
# 839                    snowing
# 840                   snowing
# 841                    snowing
# 842                   snowing
# 843                 heavy snow
# 846                    snowing
# 847                   snowing
# 848                    snowing
# 851        sn / rn heavy windy
# 852           heavy rain windy
# 853    icy, windy blowing snow
# 861                    snowing
# 862                   snowing
# 863                    snowing
# 864                   snowing
# 865                      clear
# 866                      clear
# 869                        NaN
# 870                        NaN
# 872                        NaN
# 873                        NaN
# ...                        ...
# 1602                   SNOWING
# 1603                HEAVY SNOW
# 1604                HEAVY SNOW
# 1605                HEAVY SNOW
# 1606                HEAVY SNOW
# 1607                HEAVY SNOW
# 1608            HEAVY WET SNOW
# 1609            HEAVY WET SNOW
# 1610            HEAVY WET SNOW
# 1611                HEAVY SNOW
# 1612                HEAVY SNOW
# 1613                HEAVY SNOW
# 1614                   SNOWING
# 1615  OVERCAST OCCASIONAL RAIN
# 1616                   RAINING
# 1617                   RAINING
# 1618              SNOWING HARD
# 1619                HEAVY SNOW
# 1620                HEAVY SNOW
# 1621               HEAVY SNOW
# 1622               HEAVY SNOW
# 1623               HEAVY SNOW
# 1624               HEAVY SNOW
# 1625               HEAVY SNOW
# 1626               HEAVY SNOW
# 1627               HEAVY SNOW
# 1628                       FOG
# 1629                       FOG
# 1630               HEAVY SNOW
# 1631               HEAVY SNOW
#
# [775 rows x 11 columns]

# %%
df['WEATHER'].unique()
# Out:
# array(['Raining', 'Mixed rain snow', 'snowing', 'snowing ', 'heavy snow',
#        'sn / rn heavy windy', 'heavy rain windy',
#        'icy, windy blowing snow', 'clear', nan,
#        'snowing heavy snow on roadway ', 'scattered slush places',
#        'occ. Snow snow and ice', 'heavy snow squalls', 'light snow',
#        'snowing snow and slush', 'pt. cloudy bare and wet',
#        'raining bare and wet', 'raining heavy', 'snowing heavy',
#        'Rn Sn mixed', 'SNOWING', 'lt. snow shrs.', 'snow showers',
#        'Clear', 'SNOWING & BLOWING', 'Snowing', 'lt. snow',
#        'Heavy Snowfall ', 'Hevy Snowfall', 'raining', 'Very heavy rain',
#        'overcast', 'sno showers', 'snowing poor visibility', 'RAINING',
#        'Snowing heavy', 'SNOWING HEAVY', ' SNOWING / BLOWING', 'SNOWING ',
#        'CLEAR', 'Mixed Rain / Snow', 'LIGHT RAIN',
#        'HEAVY RAIN TO HEAVY SNOW', 'LIGHT SNOW', 'OCC. SNOW', 'OVERCAST',
#        'RAIN/SNO MIX  STRONG WINDS', 'HEAVY RAIN FOLLOWING HEAVY SNOW',
#        'MIXED RAIN/SNOW', 'HEAVY RAIN ', 'HEAVY SNOW SHOWERS',
#        'FREEZING RAIN', 'FAIR', 'SNOWING HEAVILY', 'SNOWING HARD ',
#        'FLURRIES ', 'SCATTERED CLOUDS', 'BROKEN CLOUDS', 'PARTLY CLOUDY',
#        'RAINING LIGHTLY', 'RAINING   ', 'RAINING ', 'SNOWING LIGHTLY',
#        'CLEAR PATCHY FOG', 'HEAVY CONVERGENCE ZONE  SNOWING HEAVILY ',
#        'SNOWING LIGHT', 'RAIN / SLEET', 'SNOW/FRZ RAIN',
#        'OVERCAST GUSTY WINDS', 'MODERATE TO HEAVY FREEZING RAIN',
#        'HEAVY SNOW', 'HEAVY SNOW TO FREEZING RAIN / SLEET',
#        'SNOW TO RAIN', 'RAIN', 'snow', 'HEAVY WET SNOW',
#        'OVERCAST OCCASIONAL RAIN', 'SNOWING HARD', 'HEAVY SNOW ', 'FOG'],
#       dtype=object)

# %%
date = pd.to_datetime(df['date'])

# %%
westbound.index = date.index

# %%
snow.index = date.index

# %%
delay = df['delay']

# %%
delay.index = date.index

# %%
cleaned_df = pd.concat([date, delay, westbound, snow], axis=1)

# %%
cleaned_df
# Out:
#                    date     delay      0  WEATHER
# 0   2007-01-02 14:31:00  02:14:00  False    False
# 1   2007-01-02 15:00:00  00:44:00   True    False
# 2   2007-01-02 19:23:00  00:10:00   True    False
# 3   2007-01-03 11:28:00  00:12:00   True     True
# 4   2007-01-03 11:29:00  00:17:00  False     True
# 5   2007-01-05 00:01:00  00:15:00  False     True
# 6   2007-01-05 00:02:00  00:09:00   True     True
# 7   2007-01-05 19:29:00  00:22:00  False     True
# 8   2007-01-05 19:29:00  00:15:00   True     True
# 9   2007-01-06 00:26:00  00:20:00  False     True
# 10  2007-01-06 00:25:00  00:16:00   True     True
# 11  2007-01-06 03:42:00  01:13:00  False     True
# 12  2007-01-06 03:43:00  00:38:00   True     True
# 13  2007-01-07 08:46:00  02:00:00  False     True
# 14  2007-01-07 12:05:00  02:12:00  False     True
# 15  2007-01-07 12:10:00  02:07:00   True     True
# 16  2007-01-07 13:23:00  00:54:00  False     True
# 17  2007-01-07 17:12:00  00:26:00   True     True
# 18  2007-01-07 20:02:00  02:15:00  False    False
# 19  2007-01-16 10:12:00  03:29:00   True     True
# 20  2007-01-18 20:27:00  00:16:00  False     True
# 21  2007-01-18 20:29:00  00:35:00   True     True
# 22  2007-01-20 14:00:00  00:18:00  False     True
# 23  2007-01-20 14:00:00  00:18:00   True     True
# 24  2007-01-26 15:02:00  00:17:00  False    False
# 25  2007-01-31 10:17:00  05:17:00  False    False
# 26  2007-02-05 22:33:00  00:13:00   True    False
# 27  2007-02-05 22:28:00  00:25:00  False    False
# 28  2007-02-20 08:15:00  00:38:00   True    False
# 29  2007-02-20 08:17:00  00:42:00  False    False
# ..                  ...       ...    ...      ...
# 745 2017-11-03 17:23:00  04:14:00   True     True
# 746 2017-11-05 11:12:00  03:33:00   True     True
# 747 2017-11-05 11:29:00  03:02:00  False     True
# 748 2017-11-19 20:05:00  02:27:00   True     True
# 749 2017-12-19 07:56:00  02:07:00  False     True
# 750 2017-12-19 10:50:00  01:35:00  False     True
# 751 2018-01-11 06:58:00  01:20:00  False     True
# 752 2018-01-11 10:19:00  01:20:00  False     True
# 753 2018-01-11 12:44:00  07:06:00  False     True
# 754 2018-01-23 17:54:00  02:08:00  False     True
# 755 2018-01-26 10:33:00  02:06:00  False     True
# 756 2018-01-26 11:10:00  01:40:00   True     True
# 757 2018-01-27 04:30:00  00:45:00  False     True
# 758 2018-01-27 20:54:00  00:51:00  False    False
# 759 2018-02-02 02:00:00  00:30:00  False    False
# 760 2018-02-02 02:10:00  00:24:00   True    False
# 761 2018-02-16 06:28:00  02:12:00  False     True
# 762 2018-02-17 09:17:00  00:38:00  False     True
# 763 2018-02-17 12:03:00  00:31:00   True     True
# 764 2018-02-18 18:43:00  01:30:00  False     True
# 765 2018-03-04 11:27:00  02:18:00   True     True
# 766 2018-03-04 12:13:00  01:32:00   True     True
# 767 2018-03-04 11:36:00  02:13:00  False     True
# 768 2018-03-04 18:02:00  05:58:00  False     True
# 769 2018-03-04 18:21:00  05:39:00   True     True
# 770 2018-03-04 20:31:00  03:29:00  False     True
# 771 2018-03-29 09:02:00  00:37:00  False    False
# 772 2018-03-29 09:02:00  00:40:00   True    False
# 773 2018-04-01 22:29:00  09:12:00   True     True
# 774 2018-04-01 23:09:00  08:49:00  False     True
#
# [775 rows x 4 columns]

# %%
cleaned_df.rename(columns={0:'westbound', 'WEATHER':'snow'}, inplace=True)

# %%
cleaned_df
# Out:
#                    date     delay  westbound   snow
# 0   2007-01-02 14:31:00  02:14:00      False  False
# 1   2007-01-02 15:00:00  00:44:00       True  False
# 2   2007-01-02 19:23:00  00:10:00       True  False
# 3   2007-01-03 11:28:00  00:12:00       True   True
# 4   2007-01-03 11:29:00  00:17:00      False   True
# 5   2007-01-05 00:01:00  00:15:00      False   True
# 6   2007-01-05 00:02:00  00:09:00       True   True
# 7   2007-01-05 19:29:00  00:22:00      False   True
# 8   2007-01-05 19:29:00  00:15:00       True   True
# 9   2007-01-06 00:26:00  00:20:00      False   True
# 10  2007-01-06 00:25:00  00:16:00       True   True
# 11  2007-01-06 03:42:00  01:13:00      False   True
# 12  2007-01-06 03:43:00  00:38:00       True   True
# 13  2007-01-07 08:46:00  02:00:00      False   True
# 14  2007-01-07 12:05:00  02:12:00      False   True
# 15  2007-01-07 12:10:00  02:07:00       True   True
# 16  2007-01-07 13:23:00  00:54:00      False   True
# 17  2007-01-07 17:12:00  00:26:00       True   True
# 18  2007-01-07 20:02:00  02:15:00      False  False
# 19  2007-01-16 10:12:00  03:29:00       True   True
# 20  2007-01-18 20:27:00  00:16:00      False   True
# 21  2007-01-18 20:29:00  00:35:00       True   True
# 22  2007-01-20 14:00:00  00:18:00      False   True
# 23  2007-01-20 14:00:00  00:18:00       True   True
# 24  2007-01-26 15:02:00  00:17:00      False  False
# 25  2007-01-31 10:17:00  05:17:00      False  False
# 26  2007-02-05 22:33:00  00:13:00       True  False
# 27  2007-02-05 22:28:00  00:25:00      False  False
# 28  2007-02-20 08:15:00  00:38:00       True  False
# 29  2007-02-20 08:17:00  00:42:00      False  False
# ..                  ...       ...        ...    ...
# 745 2017-11-03 17:23:00  04:14:00       True   True
# 746 2017-11-05 11:12:00  03:33:00       True   True
# 747 2017-11-05 11:29:00  03:02:00      False   True
# 748 2017-11-19 20:05:00  02:27:00       True   True
# 749 2017-12-19 07:56:00  02:07:00      False   True
# 750 2017-12-19 10:50:00  01:35:00      False   True
# 751 2018-01-11 06:58:00  01:20:00      False   True
# 752 2018-01-11 10:19:00  01:20:00      False   True
# 753 2018-01-11 12:44:00  07:06:00      False   True
# 754 2018-01-23 17:54:00  02:08:00      False   True
# 755 2018-01-26 10:33:00  02:06:00      False   True
# 756 2018-01-26 11:10:00  01:40:00       True   True
# 757 2018-01-27 04:30:00  00:45:00      False   True
# 758 2018-01-27 20:54:00  00:51:00      False  False
# 759 2018-02-02 02:00:00  00:30:00      False  False
# 760 2018-02-02 02:10:00  00:24:00       True  False
# 761 2018-02-16 06:28:00  02:12:00      False   True
# 762 2018-02-17 09:17:00  00:38:00      False   True
# 763 2018-02-17 12:03:00  00:31:00       True   True
# 764 2018-02-18 18:43:00  01:30:00      False   True
# 765 2018-03-04 11:27:00  02:18:00       True   True
# 766 2018-03-04 12:13:00  01:32:00       True   True
# 767 2018-03-04 11:36:00  02:13:00      False   True
# 768 2018-03-04 18:02:00  05:58:00      False   True
# 769 2018-03-04 18:21:00  05:39:00       True   True
# 770 2018-03-04 20:31:00  03:29:00      False   True
# 771 2018-03-29 09:02:00  00:37:00      False  False
# 772 2018-03-29 09:02:00  00:40:00       True  False
# 773 2018-04-01 22:29:00  09:12:00       True   True
# 774 2018-04-01 23:09:00  08:49:00      False   True
#
# [775 rows x 4 columns]

# %%
cleaned_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 775 entries, 0 to 774
# Data columns (total 4 columns):
# date         775 non-null datetime64[ns]
# delay        775 non-null object
# westbound    775 non-null bool
# snow         775 non-null bool
# dtypes: bool(2), datetime64[ns](1), object(1)
# memory usage: 13.7+ KB
