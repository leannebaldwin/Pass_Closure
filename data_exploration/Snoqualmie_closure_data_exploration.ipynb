# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_excel('Cumulative_Snoqualmie_Pass_Delay_Closures_1992_2018.xlsx', header=[1])

# %%
data.head()
# Out:
#   INCIDENT START TIMES FOR EACH DIRECTION SECONDARY INCIDENTS START TIMES  \
# 0                     1992-11-21 12:25:00                             NaN
# 1                     1992-11-21 13:13:00                             NaN
# 2                     1992-11-21 14:30:00                             NaN
# 3                     1992-11-21 14:33:00                             NaN
# 4                     1992-11-30 18:28:00                             NaN
#
#   DIRECTION GEOGRAPHIC   MP TYPE  \
# 0        WB        NaN  NaN  NaN
# 1        EB        NaN  NaN  NaN
# 2        EB        NaN  NaN  NaN
# 3        WB        NaN  NaN  NaN
# 4        EB        NaN  NaN  NaN
#
#                                REMARKS / DESCRIPTION  \
# 0  MP 56 & 52 TEMP DELAY TO ENABLE SEARCH & RESCU...
# 1  MP 56 & 52 TEMP DELAY TO ENABLE SEARCH & RESCU...
# 2  DELAYS DUE TO SPUNOUT TRUCKS TRAFFIC WORKING T...
# 3             LOG TRUCK ACCIDENT LOG BLOCKING LANE 3
# 4          EB 60 TANKER / CAR COLLISION PT. BLOCKING
#
#   INCIDENT END TIMES - DIRECTIONAL SECONDARY INCIDENTS END TIMES  \
# 0              1992-11-21 13:00:00                           NaN
# 1              1992-11-21 14:05:00                           NaN
# 2              1992-11-21 15:30:00                           NaN
# 3              1992-11-21 15:30:00                           NaN
# 4              1992-11-30 22:10:00                           NaN
#
#   Delay Time Total WEATHER  Unnamed: 11 Unnamed: 12  Unnamed: 13 Unnamed: 14
# 0         00:35:00     NaN          NaN         NaN          NaN         NaN
# 1         00:52:00     NaN          NaN         NaN          NaN         NaN
# 2         01:00:00     NaN          NaN         NaN          NaN         NaN
# 3         00:57:00     NaN          NaN         NaN          NaN         NaN
# 4         03:42:00     NaN          NaN         NaN          NaN         NaN

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1671 entries, 0 to 1670
# Data columns (total 15 columns):
# INCIDENT START TIMES FOR EACH DIRECTION    1578 non-null object
# SECONDARY INCIDENTS START TIMES            73 non-null object
# DIRECTION                                  1628 non-null object
# GEOGRAPHIC                                 843 non-null object
# MP                                         908 non-null object
# TYPE                                       709 non-null object
#  REMARKS / DESCRIPTION                     1665 non-null object
# INCIDENT END TIMES - DIRECTIONAL           1553 non-null object
# SECONDARY INCIDENTS END TIMES              65 non-null object
# Delay Time Total                           1640 non-null object
# WEATHER                                    628 non-null object
# Unnamed: 11                                0 non-null float64
# Unnamed: 12                                24 non-null object
# Unnamed: 13                                0 non-null float64
# Unnamed: 14                                26 non-null object
# dtypes: float64(2), object(13)
# memory usage: 195.9+ KB

# %%
data.drop(data.columns[[11,12,13,14]], axis=1, inplace=True)

# %%
data.head()
# Out:
#   INCIDENT START TIMES FOR EACH DIRECTION SECONDARY INCIDENTS START TIMES  \
# 0                     1992-11-21 12:25:00                             NaN
# 1                     1992-11-21 13:13:00                             NaN
# 2                     1992-11-21 14:30:00                             NaN
# 3                     1992-11-21 14:33:00                             NaN
# 4                     1992-11-30 18:28:00                             NaN
#
#   DIRECTION GEOGRAPHIC   MP TYPE  \
# 0        WB        NaN  NaN  NaN
# 1        EB        NaN  NaN  NaN
# 2        EB        NaN  NaN  NaN
# 3        WB        NaN  NaN  NaN
# 4        EB        NaN  NaN  NaN
#
#                                REMARKS / DESCRIPTION  \
# 0  MP 56 & 52 TEMP DELAY TO ENABLE SEARCH & RESCU...
# 1  MP 56 & 52 TEMP DELAY TO ENABLE SEARCH & RESCU...
# 2  DELAYS DUE TO SPUNOUT TRUCKS TRAFFIC WORKING T...
# 3             LOG TRUCK ACCIDENT LOG BLOCKING LANE 3
# 4          EB 60 TANKER / CAR COLLISION PT. BLOCKING
#
#   INCIDENT END TIMES - DIRECTIONAL SECONDARY INCIDENTS END TIMES  \
# 0              1992-11-21 13:00:00                           NaN
# 1              1992-11-21 14:05:00                           NaN
# 2              1992-11-21 15:30:00                           NaN
# 3              1992-11-21 15:30:00                           NaN
# 4              1992-11-30 22:10:00                           NaN
#
#   Delay Time Total WEATHER
# 0         00:35:00     NaN
# 1         00:52:00     NaN
# 2         01:00:00     NaN
# 3         00:57:00     NaN
# 4         03:42:00     NaN

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1671 entries, 0 to 1670
# Data columns (total 11 columns):
# INCIDENT START TIMES FOR EACH DIRECTION    1578 non-null object
# SECONDARY INCIDENTS START TIMES            73 non-null object
# DIRECTION                                  1628 non-null object
# GEOGRAPHIC                                 843 non-null object
# MP                                         908 non-null object
# TYPE                                       709 non-null object
#  REMARKS / DESCRIPTION                     1665 non-null object
# INCIDENT END TIMES - DIRECTIONAL           1553 non-null object
# SECONDARY INCIDENTS END TIMES              65 non-null object
# Delay Time Total                           1640 non-null object
# WEATHER                                    628 non-null object
# dtypes: object(11)
# memory usage: 143.7+ KB

# %%
data.tail().T
# Out:
#                                                                      1666  \
# INCIDENT START TIMES FOR EACH DIRECTION               2018-03-29 09:02:00
# DIRECTION                                                              EB
# GEOGRAPHIC                                         NORTH BEND DENNY CREEK
# MP                                                                  34/47
# TYPE                                     SCHEDULED AVALANCHE CONTROL WORK
#  REMARKS / DESCRIPTION                                       TANK MISSION
# INCIDENT END TIMES - DIRECTIONAL                      2018-03-29 09:39:00
# Delay Time Total                                                 00:37:00
# WEATHER                                                               FOG
#
#                                                                      1667  \
# INCIDENT START TIMES FOR EACH DIRECTION               2018-03-29 09:02:00
# DIRECTION                                                              WB
# GEOGRAPHIC                                                  EASTON, MP 52
# MP                                                                  52/70
# TYPE                                     SCHEDULED AVALANCHE CONTROL WORK
#  REMARKS / DESCRIPTION                                       TANK MISSION
# INCIDENT END TIMES - DIRECTIONAL                      2018-03-29 09:42:00
# Delay Time Total                                                 00:40:00
# WEATHER                                                               FOG
#
#                                                                                       1668  \
# INCIDENT START TIMES FOR EACH DIRECTION                                2018-04-01 22:29:00
# DIRECTION                                                                               WB
# GEOGRAPHIC                                           EASTON/GOLD CREEK/CLE ELUM/ELLENSBURG
# MP                                                                            56/70/84/106
# TYPE                                                                           WX/TRACTION
#  REMARKS / DESCRIPTION                   MULTIPLE UNCHAINED & SPUN OUT VEHICLES AND MUL...
# INCIDENT END TIMES - DIRECTIONAL                                       2018-04-02 07:41:00
# Delay Time Total                                                                  09:12:00
# WEATHER                                                                        HEAVY SNOW
#
#                                                                                       1669  \
# INCIDENT START TIMES FOR EACH DIRECTION                                2018-04-01 23:09:00
# DIRECTION                                                                               EB
# GEOGRAPHIC                                                          NORTH BEND/DENNY CREEK
# MP                                                                                   34/47
# TYPE                                                                           WX/TRACTION
#  REMARKS / DESCRIPTION                   MULTIPLE UNCHAINED & SPUN OUT VEHICLES AND MUL...
# INCIDENT END TIMES - DIRECTIONAL                                       2018-04-02 07:58:00
# Delay Time Total                                                                  08:49:00
# WEATHER                                                                        HEAVY SNOW
#
#                                                                1670
# INCIDENT START TIMES FOR EACH DIRECTION   Winter Season 2017 - 2018
# DIRECTION                                                       NaN
# GEOGRAPHIC                                                      NaN
# MP                                                              NaN
# TYPE                                                            NaN
#  REMARKS / DESCRIPTION                   TOTAL SEASON SNOWFALL 446"
# INCIDENT END TIMES - DIRECTIONAL                                NaN
# Delay Time Total                                                NaN
# WEATHER                                                         NaN

# %%
data.drop(data.columns[[1,8]], axis=1, inplace=True)

# %%
data.head(10).T
# Out:
#                                                                                          0  \
# INCIDENT START TIMES FOR EACH DIRECTION                                1992-11-21 12:25:00
# DIRECTION                                                                               WB
# GEOGRAPHIC                                                                             NaN
# MP                                                                                     NaN
# TYPE                                                                                   NaN
#  REMARKS / DESCRIPTION                   MP 56 & 52 TEMP DELAY TO ENABLE SEARCH & RESCU...
# INCIDENT END TIMES - DIRECTIONAL                                       1992-11-21 13:00:00
# Delay Time Total                                                                  00:35:00
# WEATHER                                                                                NaN
#
#                                                                                          1  \
# INCIDENT START TIMES FOR EACH DIRECTION                                1992-11-21 13:13:00
# DIRECTION                                                                               EB
# GEOGRAPHIC                                                                             NaN
# MP                                                                                     NaN
# TYPE                                                                                   NaN
#  REMARKS / DESCRIPTION                   MP 56 & 52 TEMP DELAY TO ENABLE SEARCH & RESCU...
# INCIDENT END TIMES - DIRECTIONAL                                       1992-11-21 14:05:00
# Delay Time Total                                                                  00:52:00
# WEATHER                                                                                NaN
#
#                                                                                          2  \
# INCIDENT START TIMES FOR EACH DIRECTION                                1992-11-21 14:30:00
# DIRECTION                                                                               EB
# GEOGRAPHIC                                                                             NaN
# MP                                                                                     NaN
# TYPE                                                                                   NaN
#  REMARKS / DESCRIPTION                   DELAYS DUE TO SPUNOUT TRUCKS TRAFFIC WORKING T...
# INCIDENT END TIMES - DIRECTIONAL                                       1992-11-21 15:30:00
# Delay Time Total                                                                  01:00:00
# WEATHER                                                                                NaN
#
#                                                                               3  \
# INCIDENT START TIMES FOR EACH DIRECTION                     1992-11-21 14:33:00
# DIRECTION                                                                    WB
# GEOGRAPHIC                                                                  NaN
# MP                                                                          NaN
# TYPE                                                                        NaN
#  REMARKS / DESCRIPTION                   LOG TRUCK ACCIDENT LOG BLOCKING LANE 3
# INCIDENT END TIMES - DIRECTIONAL                            1992-11-21 15:30:00
# Delay Time Total                                                       00:57:00
# WEATHER                                                                     NaN
#
#                                                                                  4  \
# INCIDENT START TIMES FOR EACH DIRECTION                        1992-11-30 18:28:00
# DIRECTION                                                                       EB
# GEOGRAPHIC                                                                     NaN
# MP                                                                             NaN
# TYPE                                                                           NaN
#  REMARKS / DESCRIPTION                   EB 60 TANKER / CAR COLLISION PT. BLOCKING
# INCIDENT END TIMES - DIRECTIONAL                               1992-11-30 22:10:00
# Delay Time Total                                                          03:42:00
# WEATHER                                                                        NaN
#
#                                                                               5  \
# INCIDENT START TIMES FOR EACH DIRECTION                     1992-12-08 05:19:00
# DIRECTION                                                                    EB
# GEOGRAPHIC                                                                  NaN
# MP                                                                          NaN
# TYPE                                                                        NaN
#  REMARKS / DESCRIPTION                   36 LANES BLOCKED DUE TO SPUN OUT SEMIS
# INCIDENT END TIMES - DIRECTIONAL                            1992-12-08 06:06:00
# Delay Time Total                                                       00:47:00
# WEATHER                                                                     NaN
#
#                                                                            6  \
# INCIDENT START TIMES FOR EACH DIRECTION                                  NaN
# DIRECTION                                                                 EB
# GEOGRAPHIC                                                               NaN
# MP                                                                       NaN
# TYPE                                                                     NaN
#  REMARKS / DESCRIPTION                   EB STOPPED AT EDGEWICK DUE TO ABOVE
# INCIDENT END TIMES - DIRECTIONAL                                         NaN
# Delay Time Total                                                    00:00:00
# WEATHER                                                                  NaN
#
#                                                                                 7  \
# INCIDENT START TIMES FOR EACH DIRECTION                       1992-12-08 16:19:00
# DIRECTION                                                                      EB
# GEOGRAPHIC                                                                    NaN
# MP                                                                            NaN
# TYPE                                                                          NaN
#  REMARKS / DESCRIPTION                   47 AVALANCHE CONTROL AIRPLANE CURVE 51.5
# INCIDENT END TIMES - DIRECTIONAL                              1992-12-08 16:40:00
# Delay Time Total                                                         00:21:00
# WEATHER                                                                       NaN
#
#                                                                            8  \
# INCIDENT START TIMES FOR EACH DIRECTION                  1992-12-09 10:28:00
# DIRECTION                                                                 EB
# GEOGRAPHIC                                                               NaN
# MP                                                                       NaN
# TYPE                                                                     NaN
#  REMARKS / DESCRIPTION                   56 AVALANCHE CONTROL EAST SNOW SHED
# INCIDENT END TIMES - DIRECTIONAL                         1992-12-09 10:45:00
# Delay Time Total                                                    00:17:00
# WEATHER                                                                  NaN
#
#                                                                                 9
# INCIDENT START TIMES FOR EACH DIRECTION                       1992-12-10 08:43:00
# DIRECTION                                                                     EB
# GEOGRAPHIC                                                                    NaN
# MP                                                                            NaN
# TYPE                                                                          NaN
#  REMARKS / DESCRIPTION                   47 AVALANCHE CONTROL AIRPLANE CURVE 51.5
# INCIDENT END TIMES - DIRECTIONAL                              1992-12-10 09:22:00
# Delay Time Total                                                         00:39:00
# WEATHER                                                                       NaN

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1671 entries, 0 to 1670
# Data columns (total 9 columns):
# INCIDENT START TIMES FOR EACH DIRECTION    1578 non-null object
# DIRECTION                                  1628 non-null object
# GEOGRAPHIC                                 843 non-null object
# MP                                         908 non-null object
# TYPE                                       709 non-null object
#  REMARKS / DESCRIPTION                     1665 non-null object
# INCIDENT END TIMES - DIRECTIONAL           1553 non-null object
# Delay Time Total                           1640 non-null object
# WEATHER                                    628 non-null object
# dtypes: object(9)
# memory usage: 117.6+ KB

# %%
data.tail()
# Out:
#      INCIDENT START TIMES FOR EACH DIRECTION DIRECTION  \
# 1666                     2018-03-29 09:02:00        EB
# 1667                     2018-03-29 09:02:00        WB
# 1668                     2018-04-01 22:29:00        WB
# 1669                     2018-04-01 23:09:00        EB
# 1670               Winter Season 2017 - 2018       NaN
#
#                                  GEOGRAPHIC            MP  \
# 1666                 NORTH BEND DENNY CREEK         34/47
# 1667                          EASTON, MP 52         52/70
# 1668  EASTON/GOLD CREEK/CLE ELUM/ELLENSBURG  56/70/84/106
# 1669                 NORTH BEND/DENNY CREEK         34/47
# 1670                                    NaN           NaN
#
#                                   TYPE  \
# 1666  SCHEDULED AVALANCHE CONTROL WORK
# 1667  SCHEDULED AVALANCHE CONTROL WORK
# 1668                       WX/TRACTION
# 1669                       WX/TRACTION
# 1670                               NaN
#
#                                   REMARKS / DESCRIPTION  \
# 1666                                       TANK MISSION
# 1667                                       TANK MISSION
# 1668  MULTIPLE UNCHAINED & SPUN OUT VEHICLES AND MUL...
# 1669  MULTIPLE UNCHAINED & SPUN OUT VEHICLES AND MUL...
# 1670                         TOTAL SEASON SNOWFALL 446"
#
#      INCIDENT END TIMES - DIRECTIONAL Delay Time Total      WEATHER
# 1666              2018-03-29 09:39:00         00:37:00          FOG
# 1667              2018-03-29 09:42:00         00:40:00          FOG
# 1668              2018-04-02 07:41:00         09:12:00  HEAVY SNOW
# 1669              2018-04-02 07:58:00         08:49:00  HEAVY SNOW
# 1670                              NaN              NaN          NaN

# %%
data['INCIDENT START TIMES FOR EACH DIRECTION'].str.contains('Winter')
# Out:
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
# 5        NaN
# 6        NaN
# 7        NaN
# 8        NaN
# 9        NaN
# 10       NaN
# 11       NaN
# 12       NaN
# 13       NaN
# 14       NaN
# 15       NaN
# 16       NaN
# 17       NaN
# 18       NaN
# 19       NaN
# 20       NaN
# 21       NaN
# 22       NaN
# 23       NaN
# 24       NaN
# 25       NaN
# 26       NaN
# 27       NaN
# 28       NaN
# 29       NaN
#         ...
# 1641     NaN
# 1642     NaN
# 1643     NaN
# 1644     NaN
# 1645     NaN
# 1646     NaN
# 1647     NaN
# 1648     NaN
# 1649     NaN
# 1650     NaN
# 1651     NaN
# 1652     NaN
# 1653     NaN
# 1654     NaN
# 1655     NaN
# 1656     NaN
# 1657     NaN
# 1658     NaN
# 1659     NaN
# 1660     NaN
# 1661     NaN
# 1662     NaN
# 1663     NaN
# 1664     NaN
# 1665     NaN
# 1666     NaN
# 1667     NaN
# 1668     NaN
# 1669     NaN
# 1670    True
# Name: INCIDENT START TIMES FOR EACH DIRECTION, Length: 1671, dtype: object
