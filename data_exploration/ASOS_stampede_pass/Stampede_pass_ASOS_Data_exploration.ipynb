# %%
import pandas as pd

# %%
data = pd.read_csv('SMP-2.txt')
# Out:
# /Users/leanne/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2698: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
data.head().T
# Out:
#                                                           0  \
# station                                                 SMP
# valid                                      2006-12-31 23:56
# tmpf                                                  23.00
#  dwpf                                                 19.04
#  relh                                                 84.54
#  drct                                                100.00
#  sknt                                                  5.00
#  p01i                                                     M
#  alti                                                 30.25
#  mslp                                               1028.10
#  vsby                                                 10.00
#  gust                                                     M
#  skyc1                                                  BKN
#  skyc2                                                  OVC
#  skyc3
# ...

# %%
data.tail().T
# Out:
#                                                      113409  \
# station                                                 SMP
# valid                                      2018-08-30 23:32
# tmpf                                                  50.00
#  dwpf                                                 50.00
#  relh                                                100.00
#  drct                                                     M
#  sknt                                                  4.00
#  p01i                                                     0
#  alti                                                 30.10
#  mslp                                                     M
#  vsby                                                  0.75
#  gust                                                     M
#  skyc1                                                  VV
#  skyc2                                                    M
#  skyc3                                                    M
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 113414 entries, 0 to 113413
# Data columns (total 22 columns):
# station     113414 non-null object
# valid       113414 non-null object
# tmpf        113414 non-null object
#  dwpf       113414 non-null object
#  relh       113414 non-null object
#  drct       113414 non-null object
#  sknt       113414 non-null object
#  p01i       113414 non-null object
#  alti       113414 non-null object
#  mslp       113414 non-null object
#  vsby       113414 non-null object
#  gust       113414 non-null object
#  skyc1      113414 non-null object
#  skyc2      113414 non-null object
#  skyc3      113414 non-null object
#  skyc4      113414 non-null object
#  skyl1      113414 non-null object
#  skyl2      113414 non-null object
#  skyl3      113414 non-null object
#  skyl4      113414 non-null object
#  wxcodes    113414 non-null object
#  metar      113414 non-null object
# dtypes: object(22)
# memory usage: 19.0+ MB

# %%
data.T
# Out:
#                                                      0       \
# station                                                 SMP
# valid                                      2006-12-31 23:56
# tmpf                                                  23.00
#  dwpf                                                 19.04
#  relh                                                 84.54
#  drct                                                100.00
#  sknt                                                  5.00
#  p01i                                                     M
#  alti                                                 30.25
#  mslp                                               1028.10
#  vsby                                                 10.00
#  gust                                                     M
#  skyc1                                                  BKN
#  skyc2                                                  OVC
#  skyc3
# ...
