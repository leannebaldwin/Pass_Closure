# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data901 = pd.read_csv('TrafficPtrS901_2007-01_2018-10_All.csv/TrafficVolumeByHour_S901_2007-01_2018-10.csv')

# %%
data901.head().T
# Out:
#                                                                  0  \
# SiteId                                                        S901
# SiteLocation     On SR 090 at milepost 47.71 A: AT TINKHAM ROAD...
# Date                                                      1/1/2007
# DayOfWeek                                                   Monday
# TravelDirection                                          Eastbound
# Hour1                                                           34
# Hour2                                                           51
# Hour3                                                           40
# Hour4                                                           27
# Hour5                                                           44
# Hour6                                                           64
# Hour7                                                           95
# Hour8                                                          255
# ...

# %%
data901.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7015 entries, 0 to 7014
# Data columns (total 29 columns):
# SiteId             7015 non-null object
# SiteLocation       7015 non-null object
# Date               7015 non-null object
# DayOfWeek          7015 non-null object
# TravelDirection    7015 non-null object
# Hour1              7015 non-null int64
# Hour2              7015 non-null int64
# Hour3              7015 non-null int64
# Hour4              7015 non-null int64
# Hour5              7015 non-null int64
# Hour6              7015 non-null int64
# Hour7              7015 non-null int64
# Hour8              7015 non-null int64
# Hour9              7015 non-null int64
# Hour10             7015 non-null int64
# Hour11             7015 non-null int64
# Hour12             7015 non-null int64
# Hour13             7015 non-null int64
# Hour14             7015 non-null int64
# Hour15             7015 non-null int64
# Hour16             7015 non-null int64
# ...

# %%
data901[(data901.Hour1 < 10) | (data901.Hour2 <10) | (data901.Hour3 <10) | (data901.Hour4 <10) | (data901.Hour5 <10)
       | (data901.Hour6 <10) | (data901.Hour7 <10) | (data901.Hour8 <10) | (data901.Hour9 <10) | (data901.Hour10 <10)
       | (data901.Hour11 <10)| (data901.Hour12 <10)| (data901.Hour13 <10)| (data901.Hour14 <10)| (data901.Hour15 <10)
       | (data901.Hour16 <10)| (data901.Hour17 <10)| (data901.Hour18 <10)| (data901.Hour19 <10)| (data901.Hour20 <10)
       | (data901.Hour21 <10)| (data901.Hour22 <10)| (data901.Hour23 <10)| (data901.Hour24 <10)]
# Out:
#      SiteId                                       SiteLocation        Date  \
# 12     S901  On SR 090 at milepost 47.71 A: AT TINKHAM ROAD...    1/7/2007
# 100    S901  On SR 090 at milepost 47.71 A: AT TINKHAM ROAD...   2/20/2007
# 138    S901  On SR 090 at milepost 47.71 A: AT TINKHAM ROAD...   3/11/2007
# 139    S901  On SR 090 at milepost 47.71 A: AT TINKHAM ROAD...   3/11/2007
# 177    S901  On SR 090 at milepost 47.71 A: AT TINKHAM ROAD...   3/30/2007
# 240    S901  On SR 090 at milepost 47.71 A: AT TINKHAM ROAD...    5/1/2007
# 241    S901  On SR 090 at milepost 47.71 A: AT TINKHAM ROAD...    5/1/2007
# 747    S901  On SR 090 at milepost 47.71 A: AT TINKHAM ROAD...   1/10/2008
# 784    S901  On SR 090 at milepost 47.71 A: AT TINKHAM ROAD...   1/29/2008
# 785    S901  On SR 090 at milepost 47.71 A: AT TINKHAM ROAD...   1/29/2008
# 786    S901  On SR 090 at milepost 47.71 A: AT TINKHAM ROAD...   1/30/2008
# ...

# %%
data901.tail().T
# Out:
#                                                               7010  \
# SiteId                                                        S901
# SiteLocation     On SR 090 at milepost 47.71 A: AT TINKHAM ROAD...
# Date                                                    12/29/2017
# DayOfWeek                                                   Friday
# TravelDirection                                          Westbound
# Hour1                                                           86
# Hour2                                                           67
# Hour3                                                           59
# Hour4                                                           74
# Hour5                                                          137
# Hour6                                                          262
# Hour7                                                          240
# Hour8                                                          268
# ...

# %%
data903 = pd.read_csv('TrafficPtrS903_2007-01_2018-10_All.csv/TrafficVolumeByHour_S903_2007-01_2018-10.csv')

# %%
data903.head().T
# Out:
#                                                                  0  \
# SiteId                                                        S903
# SiteLocation     On SR 090 at milepost 63.98 A: AT CABIN CREEK ...
# Date                                                      1/1/2007
# DayOfWeek                                                   Monday
# TravelDirection                                          Eastbound
# Hour1                                                           38
# Hour2                                                           49
# Hour3                                                           45
# Hour4                                                           26
# Hour5                                                           33
# Hour6                                                           64
# Hour7                                                           86
# Hour8                                                          141
# ...

# %%
data903.tail().T
# Out:
#                                                               7552  \
# SiteId                                                        S903
# SiteLocation     On SR 090 at milepost 63.98 A: AT CABIN CREEK ...
# Date                                                     8/29/2018
# DayOfWeek                                                Wednesday
# TravelDirection                                          Westbound
# Hour1                                                          113
# Hour2                                                           99
# Hour3                                                          118
# Hour4                                                          182
# Hour5                                                          324
# Hour6                                                          556
# Hour7                                                          505
# Hour8                                                          637
# ...

# %%
data903.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7557 entries, 0 to 7556
# Data columns (total 29 columns):
# SiteId             7557 non-null object
# SiteLocation       7557 non-null object
# Date               7557 non-null object
# DayOfWeek          7557 non-null object
# TravelDirection    7557 non-null object
# Hour1              7557 non-null int64
# Hour2              7557 non-null int64
# Hour3              7557 non-null int64
# Hour4              7557 non-null int64
# Hour5              7557 non-null int64
# Hour6              7557 non-null int64
# Hour7              7557 non-null int64
# Hour8              7557 non-null int64
# Hour9              7557 non-null int64
# Hour10             7557 non-null int64
# Hour11             7557 non-null int64
# Hour12             7557 non-null int64
# Hour13             7557 non-null int64
# Hour14             7557 non-null int64
# Hour15             7557 non-null int64
# Hour16             7557 non-null int64
# ...

# %%
data903[(data903.Hour1 < 10) | (data903.Hour2 <10) | (data903.Hour3 <10) | (data903.Hour4 <10) | (data903.Hour5 <10)
       | (data903.Hour6 <10) | (data903.Hour7 <10) | (data903.Hour8 <10) | (data903.Hour9 <10) | (data903.Hour10 <10)
       | (data903.Hour11 <10)| (data903.Hour12 <10)| (data903.Hour13 <10)| (data903.Hour14 <10)| (data903.Hour15 <10)
       | (data903.Hour16 <10)| (data903.Hour17 <10)| (data903.Hour18 <10)| (data903.Hour19 <10)| (data903.Hour20 <10)
       | (data903.Hour21 <10)| (data903.Hour22 <10)| (data903.Hour23 <10)| (data903.Hour24 <10)]
# Out:
#      SiteId                                       SiteLocation        Date  \
# 5      S903  On SR 090 at milepost 63.98 A: AT CABIN CREEK ...    1/3/2007
# 12     S903  On SR 090 at milepost 63.98 A: AT CABIN CREEK ...    1/7/2007
# 136    S903  On SR 090 at milepost 63.98 A: AT CABIN CREEK ...   3/11/2007
# 137    S903  On SR 090 at milepost 63.98 A: AT CABIN CREEK ...   3/11/2007
# 175    S903  On SR 090 at milepost 63.98 A: AT CABIN CREEK ...   3/30/2007
# 656    S903  On SR 090 at milepost 63.98 A: AT CABIN CREEK ...   12/3/2007
# 657    S903  On SR 090 at milepost 63.98 A: AT CABIN CREEK ...   12/3/2007
# 736    S903  On SR 090 at milepost 63.98 A: AT CABIN CREEK ...   1/23/2008
# 739    S903  On SR 090 at milepost 63.98 A: AT CABIN CREEK ...   1/26/2008
# 742    S903  On SR 090 at milepost 63.98 A: AT CABIN CREEK ...   1/29/2008
# 743    S903  On SR 090 at milepost 63.98 A: AT CABIN CREEK ...   1/30/2008
# ...

# %%
data901_speed = pd.read_csv('TrafficPtrS901_2007-01_2018-10_All.csv/TrafficSpeedByHour_S901_2007-01_2018-10.csv')

# %%
data901_speed.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27596 entries, 0 to 27595
# Data columns (total 25 columns):
# SiteId                        27596 non-null object
# SiteLocation                  27596 non-null object
# TravelDirection               27596 non-null object
# Date                          27596 non-null object
# DayOfWeek                     27596 non-null object
# Hour                          27596 non-null int64
# TrafficVolCntOver0To5MPH      27596 non-null int64
# TrafficVolCntOver5To10MPH     27596 non-null int64
# TrafficVolCntOver10To15MPH    27596 non-null int64
# TrafficVolCntOver15To20MPH    27596 non-null int64
# TrafficVolCntOver20To25MPH    27596 non-null int64
# TrafficVolCntOver25To30MPH    27596 non-null int64
# TrafficVolCntOver30To35MPH    27596 non-null int64
# TrafficVolCntOver35To40MPH    27596 non-null int64
# TrafficVolCntOver40To45MPH    27596 non-null int64
# TrafficVolCntOver45To50MPH    27596 non-null int64
# ...

# %%
data901_speed.tail().T
# Out:
#                                                                         27591  \
# SiteId                                                                   S901
# SiteLocation                On SR 090 at milepost 47.71 A: AT TINKHAM ROAD...
# TravelDirection                                                     Westbound
# Date                                                                8/20/2018
# DayOfWeek                                                              Monday
# Hour                                                                       20
# TrafficVolCntOver0To5MPH                                                    0
# TrafficVolCntOver5To10MPH                                                   0
# TrafficVolCntOver10To15MPH                                                  0
# TrafficVolCntOver15To20MPH                                                  0
# TrafficVolCntOver20To25MPH                                                  0
# ...

# %%
data901_speed.T
# Out:
#                                                                         0      \
# SiteId                                                                   S901
# SiteLocation                On SR 090 at milepost 47.71 A: AT TINKHAM ROAD...
# TravelDirection                                                     Eastbound
# Date                                                                 1/1/2016
# DayOfWeek                                                              Friday
# Hour                                                                        1
# TrafficVolCntOver0To5MPH                                                    0
# TrafficVolCntOver5To10MPH                                                   0
# TrafficVolCntOver10To15MPH                                                  0
# TrafficVolCntOver15To20MPH                                                  0
# TrafficVolCntOver20To25MPH                                                  0
# ...

# %%
data901_traffic_stats = pd.read_csv('TrafficPtrS901_2007-01_2018-10_All.csv/MonthlyTrafficStatistics_S901_2007-01_2018-10.csv')

# %%
data901_traffic_stats.head().T
# Out:
#                                                                            0  \
# SiteId                                                                  S901
# SiteLocation               On SR 090 at milepost 47.71 A: AT TINKHAM ROAD...
# TravelDirection                                                    Eastbound
# Year                                                                    2007
# Month                                                                      1
# AvgSunday                                                              14395
# AvgMonday                                                              11736
# AvgTuesday                                                              8870
# AvgWednesday                                                            9088
# AvgThursday                                                             9881
# AvgFriday                                                              15626
# ...

# %%
data901_traffic_stats.tail().T
# Out:
#                                                                          233  \
# SiteId                                                                  S901
# SiteLocation               On SR 090 at milepost 47.71 A: AT TINKHAM ROAD...
# TravelDirection                                                    Westbound
# Year                                                                    2017
# Month                                                                     10
# AvgSunday                                                              24775
# AvgMonday                                                              13879
# AvgTuesday                                                             11982
# AvgWednesday                                                           12405
# AvgThursday                                                            14356
# AvgFriday                                                              18309
# ...

# %%
data901_traffic_stats.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 238 entries, 0 to 237
# Data columns (total 17 columns):
# SiteId                       238 non-null object
# SiteLocation                 238 non-null object
# TravelDirection              238 non-null object
# Year                         238 non-null int64
# Month                        238 non-null int64
# AvgSunday                    238 non-null int64
# AvgMonday                    238 non-null int64
# AvgTuesday                   238 non-null int64
# AvgWednesday                 238 non-null int64
# AvgThursday                  238 non-null int64
# AvgFriday                    238 non-null int64
# AvgSaturday                  238 non-null int64
# AvgDay                       238 non-null int64
# SingleUnitTruckPct           214 non-null float64
# DoubleUnitTruckPct           214 non-null float64
# TripleUnitTruckPct           214 non-null float64
# VehicleClassificationType    214 non-null object
# ...

# %%
plt.plot(data901_traffic_stats.AvgDay)

# %%
plt.show()

# %%
data901.rename(columns={'TravelDirection':'direction', 'Date':'date', 'DayOfWeek':'day'}, inplace=True)

# %%
data901.head().T
# Out:
#                                                               0  \
# SiteId                                                     S901
# SiteLocation  On SR 090 at milepost 47.71 A: AT TINKHAM ROAD...
# date                                                   1/1/2007
# day                                                      Monday
# direction                                                    EB
# Hour1                                                        34
# Hour2                                                        51
# Hour3                                                        40
# Hour4                                                        27
# Hour5                                                        44
# Hour6                                                        64
# Hour7                                                        95
# Hour8                                                       255
# Hour9                                                       683
# ...

# %%
date = pd.to_datetime(data901['date'])

# %%
date.head()
# Out:
# 0   2007-01-01
# 1   2007-01-01
# 2   2007-01-02
# 3   2007-01-02
# 4   2007-01-03
# Name: date, dtype: datetime64[ns]

# %%
data901.direction[data901.direction == 'Eastbound'] = 'EB'
# Out:
# /Users/leanne/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
data901.head()
# Out:
#   SiteId                                       SiteLocation      date  \
# 0   S901  On SR 090 at milepost 47.71 A: AT TINKHAM ROAD...  1/1/2007
# 1   S901  On SR 090 at milepost 47.71 A: AT TINKHAM ROAD...  1/1/2007
# 2   S901  On SR 090 at milepost 47.71 A: AT TINKHAM ROAD...  1/2/2007
# 3   S901  On SR 090 at milepost 47.71 A: AT TINKHAM ROAD...  1/2/2007
# 4   S901  On SR 090 at milepost 47.71 A: AT TINKHAM ROAD...  1/3/2007
#
#    DayOfWeek  direction  Hour1  Hour2  Hour3  Hour4  Hour5   ...    Hour15  \
# 0     Monday         EB     34     51     40     27     44   ...      1474
# 1     Monday  Westbound    100     62     53     36     39   ...      2250
# 2    Tuesday         EB     83     54     61     56     94   ...      1057
# 3    Tuesday  Westbound    116     76     60     83    161   ...      1162
# 4  Wednesday         EB     79     73     85     53     96   ...       778
#
#    Hour16  Hour17  Hour18  Hour19  Hour20  Hour21  Hour22  Hour23  Hour24
# ...

# %%
data901.direction[data901.direction == 'Westbound'] = 'WB'
# Out:
# /Users/leanne/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
data901.T
# Out:
#                                                            0     \
# SiteId                                                     S901
# SiteLocation  On SR 090 at milepost 47.71 A: AT TINKHAM ROAD...
# date                                                   1/1/2007
# DayOfWeek                                                Monday
# direction                                                    EB
# Hour1                                                        34
# Hour2                                                        51
# Hour3                                                        40
# Hour4                                                        27
# Hour5                                                        44
# Hour6                                                        64
# Hour7                                                        95
# Hour8                                                       255
# Hour9                                                       683
# ...

# %%
westbound = pd.Series([True if value == 'WB' else False for value in data901.direction])

# %%
westbound
# Out:
# 0       False
# 1        True
# 2       False
# 3        True
# 4       False
# 5        True
# 6       False
# 7        True
# 8       False
# 9        True
# 10      False
# 11       True
# 12      False
# 13       True
# 14      False
# 15       True
# 16      False
# 17       True
# 18      False
# 19       True
# 20      False
# 21       True
# 22      False
# 23       True
# 24      False
# 25       True
# 26      False
# 27       True
# 28      False
# 29       True
#         ...
# 6985    False
# 6986     True
# 6987    False
# 6988     True
# 6989    False
# 6990     True
# 6991    False
# 6992     True
# 6993    False
# 6994     True
# 6995    False
# 6996     True
# 6997    False
# 6998     True
# 6999    False
# 7000     True
# 7001    False
# 7002     True
# 7003    False
# 7004     True
# 7005    False
# 7006     True
# 7007    False
# 7008     True
# 7009    False
# 7010     True
# 7011    False
# 7012     True
# 7013    False
# 7014     True
# ...

# %%
date.index = westbound.index

# %%
data = data901.drop(['SiteId', 'SiteLocation', 'date', 'direction'], axis=1)

# %%
df = pd.concat([date, westbound, data], axis=1)

# %%
df.head()
# Out:
#         date      0        day  Hour1  Hour2  Hour3  Hour4  Hour5  Hour6  \
# 0 2007-01-01  False     Monday     34     51     40     27     44     64
# 1 2007-01-01   True     Monday    100     62     53     36     39     53
# 2 2007-01-02  False    Tuesday     83     54     61     56     94    163
# 3 2007-01-02   True    Tuesday    116     76     60     83    161    327
# 4 2007-01-03  False  Wednesday     79     73     85     53     96    131
#
#    Hour7   ...    Hour15  Hour16  Hour17  Hour18  Hour19  Hour20  Hour21  \
# 0     95   ...      1474    1213     932     618     345     292     218
# 1     57   ...      2250    2452    2440    2537    2303    1047     615
# 2    273   ...      1057     906     746     665     461     351     300
# 3    358   ...      1162     366    1508     733     524     430     356
# 4    234   ...       778     747     732     651     482     333     230
#
#    Hour22  Hour23  Hour24
# 0     163     124      80
# 1     440     265     178
# ...

# %%
df.rename(columns={0:'westbound'}, inplace=True)

# %%
df.T
# Out:
#                           0                    1                    2     \
# date       2007-01-01 00:00:00  2007-01-01 00:00:00  2007-01-02 00:00:00
# westbound                False                 True                False
# day                     Monday               Monday              Tuesday
# Hour1                       34                  100                   83
# Hour2                       51                   62                   54
# Hour3                       40                   53                   61
# Hour4                       27                   36                   56
# Hour5                       44                   39                   94
# Hour6                       64                   53                  163
# Hour7                       95                   57                  273
# Hour8                      255                   78                  321
# Hour9                      683                  130                  485
# ...

# %%
data903.T
# Out:
#                                                               0     \
# SiteId                                                        S903
# SiteLocation     On SR 090 at milepost 63.98 A: AT CABIN CREEK ...
# Date                                                      1/1/2007
# DayOfWeek                                                   Monday
# TravelDirection                                          Eastbound
# Hour1                                                           38
# Hour2                                                           49
# Hour3                                                           45
# Hour4                                                           26
# Hour5                                                           33
# Hour6                                                           64
# Hour7                                                           86
# Hour8                                                          141
# ...

# %%
data903.rename(columns={'TravelDirection':'direction', 'Date':'date', 'DayOfWeek':'day'}, inplace=True)

# %%
data903.T
# Out:
#                                                            0     \
# SiteId                                                     S903
# SiteLocation  On SR 090 at milepost 63.98 A: AT CABIN CREEK ...
# date                                                   1/1/2007
# day                                                      Monday
# direction                                             Eastbound
# Hour1                                                        38
# Hour2                                                        49
# Hour3                                                        45
# Hour4                                                        26
# Hour5                                                        33
# Hour6                                                        64
# Hour7                                                        86
# Hour8                                                       141
# Hour9                                                       195
# ...

# %%
date903 = pd.to_datetime(data903['date'])

# %%
date903.head()
# Out:
# 0   2007-01-01
# 1   2007-01-01
# 2   2007-01-02
# 3   2007-01-02
# 4   2007-01-03
# Name: date, dtype: datetime64[ns]

# %%
data903.direction[data903.direction == 'Eastbound'] = 'EB'
# Out:
# /Users/leanne/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
data903.direction[data903.direction == 'Westbound'] = 'WB'
# Out:
# /Users/leanne/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
data903.T
# Out:
#                                                            0     \
# SiteId                                                     S903
# SiteLocation  On SR 090 at milepost 63.98 A: AT CABIN CREEK ...
# date                                                   1/1/2007
# day                                                      Monday
# direction                                                    EB
# Hour1                                                        38
# Hour2                                                        49
# Hour3                                                        45
# Hour4                                                        26
# Hour5                                                        33
# Hour6                                                        64
# Hour7                                                        86
# Hour8                                                       141
# Hour9                                                       195
# ...

# %%
westbound903 = pd.Series([True if value == 'WB' else False for value in data903.direction])

# %%
westbound903
# Out:
# 0       False
# 1        True
# 2       False
# 3        True
# 4       False
# 5        True
# 6       False
# 7        True
# 8       False
# 9        True
# 10      False
# 11       True
# 12      False
# 13       True
# 14      False
# 15       True
# 16      False
# 17       True
# 18      False
# 19       True
# 20      False
# 21       True
# 22      False
# 23       True
# 24      False
# 25       True
# 26      False
# 27       True
# 28      False
# 29       True
#         ...
# 7527    False
# 7528     True
# 7529    False
# 7530     True
# 7531    False
# 7532     True
# 7533    False
# 7534     True
# 7535    False
# 7536     True
# 7537    False
# 7538     True
# 7539    False
# 7540     True
# 7541    False
# 7542     True
# 7543    False
# 7544     True
# 7545    False
# 7546     True
# 7547    False
# 7548     True
# 7549    False
# 7550     True
# 7551    False
# 7552     True
# 7553    False
# 7554     True
# 7555    False
# 7556     True
# ...

# %%
westbound903.index = date903.index

# %%
data903 = data903.drop(['SiteId', 'SiteLocation', 'date', 'direction'], axis=1)

# %%
data903.T
# Out:
#           0       1        2        3          4          5         6     \
# day     Monday  Monday  Tuesday  Tuesday  Wednesday  Wednesday  Thursday
# Hour1       38      45       97       89         94         72       111
# Hour2       49      40       55       80         66         81       100
# Hour3       45      35       61       58         86         69        78
# Hour4       26      37       59      118         67         80        57
# Hour5       33      25       96      193         75        183        66
# Hour6       64      53      126      364        141        310       127
# Hour7       86      47      260      348        183        298       199
# Hour8      141      97      290      354        308        336       275
# Hour9      195     133      402      395        333        381       277
# Hour10     354     259      641      534        486        442       356
# Hour11     468     558      878      693        593        434       510
# ...

# %%
df903 = pd.concat([date903, westbound903, data903], axis=1)

# %%
df903.T
# Out:
#                        0                    1                    2     \
# date    2007-01-01 00:00:00  2007-01-01 00:00:00  2007-01-02 00:00:00
# 0                     False                 True                False
# day                  Monday               Monday              Tuesday
# Hour1                    38                   45                   97
# Hour2                    49                   40                   55
# Hour3                    45                   35                   61
# Hour4                    26                   37                   59
# Hour5                    33                   25                   96
# Hour6                    64                   53                  126
# Hour7                    86                   47                  260
# Hour8                   141                   97                  290
# Hour9                   195                  133                  402
# ...

# %%
df903.rename(columns={0:'westbound'}, inplace=True)

# %%
df903.T
# Out:
#                           0                    1                    2     \
# date       2007-01-01 00:00:00  2007-01-01 00:00:00  2007-01-02 00:00:00
# westbound                False                 True                False
# day                     Monday               Monday              Tuesday
# Hour1                       38                   45                   97
# Hour2                       49                   40                   55
# Hour3                       45                   35                   61
# Hour4                       26                   37                   59
# Hour5                       33                   25                   96
# Hour6                       64                   53                  126
# Hour7                       86                   47                  260
# Hour8                      141                   97                  290
# Hour9                      195                  133                  402
# ...

# %%
cleaned_df = df903[(df903['date'] > '2017-12-31') & (df903['date'] < '2018-04-03')]

# %%
cleaned_df
# Out:
#            date  westbound        day  Hour1  Hour2  Hour3  Hour4  Hour5  \
# 7087 2018-01-01      False     Monday     54     61     61     39     39
# 7088 2018-01-01       True     Monday     57     40     39     49     45
# 7089 2018-01-02      False    Tuesday     51     57     67     63    141
# 7090 2018-01-02       True    Tuesday     84     79     86    118    312
# 7091 2018-01-03      False  Wednesday    120     93    112     97    135
# 7092 2018-01-03       True  Wednesday     69     77     77    127    279
# 7093 2018-01-04      False   Thursday     94     83     97     91    147
# 7094 2018-01-04       True   Thursday     76     68     86    120    291
# 7095 2018-01-05      False     Friday    113     88     85     97    136
# 7096 2018-01-05       True     Friday     64     83     88    116    258
# 7097 2018-01-06      False   Saturday    107     89     73     71    105
# 7098 2018-01-06       True   Saturday     54     63     51     71     96
# ...

# %%
frames = [df, cleaned_df]

# %%
result = pd.concat(frames)

# %%
result.T
# Out:
#                           0                    1                    2     \
# date       2007-01-01 00:00:00  2007-01-01 00:00:00  2007-01-02 00:00:00
# westbound                False                 True                False
# day                     Monday               Monday              Tuesday
# Hour1                       34                  100                   83
# Hour2                       51                   62                   54
# Hour3                       40                   53                   61
# Hour4                       27                   36                   56
# Hour5                       44                   39                   94
# Hour6                       64                   53                  163
# Hour7                       95                   57                  273
# Hour8                      255                   78                  321
# Hour9                      683                  130                  485
# ...
